# %%
# %cd /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/data/chars
# Out:
# /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/data/chars

# %%
# !python ../../../../../diffusion-pipe/data/process_obor_asserts/process_obor_assets.py fterry/terry.txt --offset-x-ratio 0.4222 --offset-y-ratio 0.8739 --canvas-color "#00ffff" --scale-ratio 2.0 --repeat-fill 13
# Out:
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Attempting to generate video using ffmpeg for waiting
# Generated video with ffmpeg: waiting.mp4 (7 frames)
# Attempting to generate video using ffmpeg for select
# Generated video with ffmpeg: select.mp4 (22 frames)
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (10 frames)
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (12 frames)
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (8 frames)
# Attempting to generate video using ffmpeg for run
# Generated video with ffmpeg: run.mp4 (8 frames)
# Attempting to generate video using ffmpeg for runattack
# Generated video with ffmpeg: runattack.mp4 (28 frames)
# Attempting to generate video using ffmpeg for runjumpattack
# Generated video with ffmpeg: runjumpattack.mp4 (9 frames)
# Attempting to generate video using ffmpeg for block
# Generated video with ffmpeg: block.mp4 (9 frames)
# Attempting to generate video using ffmpeg for attackup
# Generated video with ffmpeg: attackup.mp4 (7 frames)
# Attempting to generate video using ffmpeg for attackdown
# Generated video with ffmpeg: attackdown.mp4 (7 frames)
# Attempting to generate video using ffmpeg for attack1
# Generated video with ffmpeg: attack1.mp4 (6 frames)
# Attempting to generate video using ffmpeg for attack2
# Generated video with ffmpeg: attack2.mp4 (7 frames)
# Attempting to generate video using ffmpeg for attack3
# Generated video with ffmpeg: attack3.mp4 (10 frames)
# Attempting to generate video using ffmpeg for attack4
# Generated video with ffmpeg: attack4.mp4 (7 frames)
# Attempting to generate video using ffmpeg for attack5
# Generated video with ffmpeg: attack5.mp4 (10 frames)
# Attempting to generate video using ffmpeg for attack6
# Generated video with ffmpeg: attack6.mp4 (7 frames)
# Attempting to generate video using ffmpeg for attack7
# Generated video with ffmpeg: attack7.mp4 (13 frames)
# Attempting to generate video using ffmpeg for chargeattack
# Generated video with ffmpeg: chargeattack.mp4 (15 frames)
# Attempting to generate video using ffmpeg for jumpdelay
# Generated video with ffmpeg: jumpdelay.mp4 (3 frames)
# Attempting to generate video using ffmpeg for jumpland
# Generated video with ffmpeg: jumpland.mp4 (3 frames)
# Attempting to generate video using ffmpeg for jump
# Generated video with ffmpeg: jump.mp4 (11 frames)
# Attempting to generate video using ffmpeg for runjump
# Generated video with ffmpeg: runjump.mp4 (10 frames)
# Attempting to generate video using ffmpeg for jumpattack
# Generated video with ffmpeg: jumpattack.mp4 (9 frames)
# Attempting to generate video using ffmpeg for jumpattack2
# Generated video with ffmpeg: jumpattack2.mp4 (3 frames)
# Attempting to generate video using ffmpeg for special
# Generated video with ffmpeg: special.mp4 (18 frames)
# Attempting to generate video using ffmpeg for charge
# Generated video with ffmpeg: charge.mp4 (8 frames)
# Attempting to generate video using ffmpeg for cant
# Generated video with ffmpeg: cant.mp4 (11 frames)
# Attempting to generate video using ffmpeg for grab
# Generated video with ffmpeg: grab.mp4 (18 frames)
# Attempting to generate video using ffmpeg for grabattack
# Generated video with ffmpeg: grabattack.mp4 (7 frames)
# Attempting to generate video using ffmpeg for grabforward
# Generated video with ffmpeg: grabforward.mp4 (7 frames)
# Attempting to generate video using ffmpeg for grabattack2
# Generated video with ffmpeg: grabattack2.mp4 (16 frames)
# Attempting to generate video using ffmpeg for grabforward2
# Generated video with ffmpeg: grabforward2.mp4 (22 frames)
# Attempting to generate video using ffmpeg for throw
# Generated video with ffmpeg: throw.mp4 (12 frames)
# Attempting to generate video using ffmpeg for grabbed
# Generated video with ffmpeg: grabbed.mp4 (18 frames)
# Attempting to generate video using ffmpeg for pain
# Generated video with ffmpeg: pain.mp4 (5 frames)
# Attempting to generate video using ffmpeg for pain2
# Generated video with ffmpeg: pain2.mp4 (5 frames)
# Attempting to generate video using ffmpeg for pain3
# Generated video with ffmpeg: pain3.mp4 (19 frames)
# Attempting to generate video using ffmpeg for fall
# Generated video with ffmpeg: fall.mp4 (60 frames)
# Attempting to generate video using ffmpeg for fall2
# Generated video with ffmpeg: fall2.mp4 (60 frames)
# Attempting to generate video using ffmpeg for fall3
# Generated video with ffmpeg: fall3.mp4 (60 frames)
# Warning: Image not found: fterry/burn1.gif
# Warning: Image not found: fterry/burn2.gif
# Attempting to generate video using ffmpeg for burn
# Generated video with ffmpeg: burn.mp4 (4 frames)
# Attempting to generate video using ffmpeg for rise
# Generated video with ffmpeg: rise.mp4 (8 frames)
# Attempting to generate video using ffmpeg for freespecial2
# Generated video with ffmpeg: freespecial2.mp4 (19 frames)
# Attempting to generate video using ffmpeg for freespecial3
# Generated video with ffmpeg: freespecial3.mp4 (27 frames)
# Attempting to generate video using ffmpeg for freespecial4
# Generated video with ffmpeg: freespecial4.mp4 (19 frames)
# Attempting to generate video using ffmpeg for freespecial5
# Generated video with ffmpeg: freespecial5.mp4 (12 frames)
# Attempting to generate video using ffmpeg for freespecial6
# Generated video with ffmpeg: freespecial6.mp4 (15 frames)
# Attempting to generate video using ffmpeg for freespecial7
# Generated video with ffmpeg: freespecial7.mp4 (47 frames)
# Attempting to generate video using ffmpeg for freespecial8
# Generated video with ffmpeg: freespecial8.mp4 (10 frames)
# Attempting to generate video using ffmpeg for freespecial1
# Generated video with ffmpeg: freespecial1.mp4 (12 frames)
# Attempting to generate video using ffmpeg for follow1
# Generated video with ffmpeg: follow1.mp4 (77 frames)
# Generated JSON summary: terry_animations.json
#
# Animation generation completed successfully!
# Summary saved to: terry_animations.json

# %%
# !ls *.mp4
# Out:
# attack1.mp4       chargeattack.mp4  grab.mp4          pain2.mp4
# attack2.mp4       fall.mp4          grabattack.mp4    pain3.mp4
# attack3.mp4       fall2.mp4         grabattack2.mp4   rise.mp4
# attack4.mp4       fall3.mp4         grabbed.mp4       run.mp4
# attack5.mp4       follow1.mp4       grabforward.mp4   runattack.mp4
# attack6.mp4       freespecial1.mp4  grabforward2.mp4  runjump.mp4
# attack7.mp4       freespecial2.mp4  idle.mp4          runjumpattack.mp4
# attackdown.mp4    freespecial3.mp4  jump.mp4          select.mp4
# attackup.mp4      freespecial4.mp4  jumpattack.mp4    spawn.mp4
# block.mp4         freespecial5.mp4  jumpattack2.mp4   special.mp4
# burn.mp4          freespecial6.mp4  jumpdelay.mp4     throw.mp4
# cant.mp4          freespecial7.mp4  jumpland.mp4      waiting.mp4
# charge.mp4        freespecial8.mp4  pain.mp4          walk.mp4

# %%
chars_str = """1ryo/ryo.txt
1robert/robert.txt
1yuri/yuri.txt
fterry/terry.txt
fandy/andy.txt
fjoe/joe.txt
2punk1/punk1.txt
2punk2/punk2.txt
2punk3/punk3.txt
2punk4/punk4.txt
2rat/rat.txt
2lucky/lucky.txt
2brian/brian.txt
2heid/heid.txt
2shoto1/shoto1.txt
2shoto2/shoto2.txt
3todo/todo.txt
3jack/jack.txt
3jack/jack2.txt
3king/king.txt
3king/king2.txt
3lee/lee.txt
3lee/lee2.txt
3micky/micky.txt
3john/john.txt
3john/john2.txt
3big/big.txt
3karate/karate.txt
5eiji/eiji.txt
5Billy/Billy.txt
5Billy/Billy2.txt
2sold1/sold1.txt
2sold2/sold2.txt
2sold3/sold3.txt
4bike2/ghost1.txt
4bike2/ghost2.txt
4bike2/ghost3.txt
5geese/geese.txt
5geese/geesed.txt
5geese/gagent.txt"""

chars = chars_str.split("\n")
len(chars), chars[0], chars[-1]
# Out:
# (40, '1ryo/ryo.txt', '5geese/gagent.txt')

# %%
import glob
from tqdm import tqdm



for chdir in tqdm(chars):
    print(f"processing {chdir}")
    # !python ../../../../../diffusion-pipe/data/process_obor_asserts/process_obor_assets.py {chdir} --offset-x-ratio 0.4222 --offset-y-ratio 0.8739 --canvas-color "#00ffff" --scale-ratio 2.0 --repeat-fill 14
# Out:
#   0%|                                                                                                                                                                                                                                                                                              | 0/40 [00:00<?, ?it/s]
# processing 1ryo/ryo.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 14 frames
# Filling animation 'waiting' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for waiting
# Generated video with ffmpeg: waiting.mp4 (14 frames)
# Attempting to generate video using ffmpeg for select
# Generated video with ffmpeg: select.mp4 (26 frames)
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (14 frames)
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (31 frames)
# Repeating animation 'walk' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (14 frames)
# Repeating animation 'run' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for run
# Generated video with ffmpeg: run.mp4 (14 frames)
# Attempting to generate video using ffmpeg for runattack
# Generated video with ffmpeg: runattack.mp4 (26 frames)
# Filling animation 'runjumpattack' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for runjumpattack
# Generated video with ffmpeg: runjumpattack.mp4 (14 frames)
# Filling animation 'block' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for block
# Generated video with ffmpeg: block.mp4 (14 frames)
# Filling animation 'attackup' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attackup
# Generated video with ffmpeg: attackup.mp4 (14 frames)
# Filling animation 'attackdown' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attackdown
# Generated video with ffmpeg: attackdown.mp4 (14 frames)
# Filling animation 'attack1' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack1
# Generated video with ffmpeg: attack1.mp4 (14 frames)
# Filling animation 'attack2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack2
# Generated video with ffmpeg: attack2.mp4 (14 frames)
# Filling animation 'attack3' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack3
# Generated video with ffmpeg: attack3.mp4 (14 frames)
# Filling animation 'attack4' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack4
# Generated video with ffmpeg: attack4.mp4 (14 frames)
# Filling animation 'attack5' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack5
# Generated video with ffmpeg: attack5.mp4 (14 frames)
# Filling animation 'attack6' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack6
# Generated video with ffmpeg: attack6.mp4 (14 frames)
# Filling animation 'attack7' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack7
# Generated video with ffmpeg: attack7.mp4 (14 frames)
# Attempting to generate video using ffmpeg for chargeattack
# Generated video with ffmpeg: chargeattack.mp4 (27 frames)
# Filling animation 'jumpdelay' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpdelay
# Generated video with ffmpeg: jumpdelay.mp4 (14 frames)
# Filling animation 'jumpland' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpland
# Generated video with ffmpeg: jumpland.mp4 (14 frames)
# Filling animation 'jump' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jump
# Generated video with ffmpeg: jump.mp4 (14 frames)
# Filling animation 'forwardjump' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for forwardjump
# Generated video with ffmpeg: forwardjump.mp4 (14 frames)
# Filling animation 'runjump' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for runjump
# Generated video with ffmpeg: runjump.mp4 (14 frames)
# Filling animation 'jumpattack' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpattack
# Generated video with ffmpeg: jumpattack.mp4 (14 frames)
# Filling animation 'jumpattack2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpattack2
# Generated video with ffmpeg: jumpattack2.mp4 (14 frames)
# Filling animation 'jumpattack3' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpattack3
# Generated video with ffmpeg: jumpattack3.mp4 (14 frames)
# Filling animation 'follow5' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for follow5
# Generated video with ffmpeg: follow5.mp4 (14 frames)
# Filling animation 'special' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for special
# Generated video with ffmpeg: special.mp4 (14 frames)
# Filling animation 'charge' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for charge
# Generated video with ffmpeg: charge.mp4 (14 frames)
# Filling animation 'cant' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for cant
# Generated video with ffmpeg: cant.mp4 (14 frames)
# Attempting to generate video using ffmpeg for grab
# Generated video with ffmpeg: grab.mp4 (18 frames)
# Filling animation 'grabattack' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabattack
# Generated video with ffmpeg: grabattack.mp4 (14 frames)
# Filling animation 'grabforward' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabforward
# Generated video with ffmpeg: grabforward.mp4 (14 frames)
# Filling animation 'grabattack2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabattack2
# Generated video with ffmpeg: grabattack2.mp4 (14 frames)
# Filling animation 'grabforward2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabforward2
# Generated video with ffmpeg: grabforward2.mp4 (14 frames)
# Filling animation 'throw' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for throw
# Generated video with ffmpeg: throw.mp4 (14 frames)
# Attempting to generate video using ffmpeg for grabbed
# Generated video with ffmpeg: grabbed.mp4 (18 frames)
# Filling animation 'pain' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for pain
# Generated video with ffmpeg: pain.mp4 (14 frames)
# Filling animation 'pain2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for pain2
# Generated video with ffmpeg: pain2.mp4 (14 frames)
# Attempting to generate video using ffmpeg for pain3
# Generated video with ffmpeg: pain3.mp4 (19 frames)
# Attempting to generate video using ffmpeg for fall
# Generated video with ffmpeg: fall.mp4 (60 frames)
# Attempting to generate video using ffmpeg for fall2
# Generated video with ffmpeg: fall2.mp4 (60 frames)
# Attempting to generate video using ffmpeg for fall3
# Generated video with ffmpeg: fall3.mp4 (60 frames)
# Warning: Image not found: 1ryo/burn1.gif
# Warning: Image not found: 1ryo/burn2.gif
# Repeating animation 'burn' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for burn
# Generated video with ffmpeg: burn.mp4 (14 frames)
# Filling animation 'rise' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for rise
# Generated video with ffmpeg: rise.mp4 (14 frames)
# Attempting to generate video using ffmpeg for freespecial2
# Generated video with ffmpeg: freespecial2.mp4 (32 frames)
# Attempting to generate video using ffmpeg for follow2
# Generated video with ffmpeg: follow2.mp4 (18 frames)
# Attempting to generate video using ffmpeg for freespecial3
# Generated video with ffmpeg: freespecial3.mp4 (25 frames)
# Attempting to generate video using ffmpeg for freespecial4
# Generated video with ffmpeg: freespecial4.mp4 (16 frames)
# Attempting to generate video using ffmpeg for follow3
# Generated video with ffmpeg: follow3.mp4 (70 frames)
# Attempting to generate video using ffmpeg for freespecial5
# Generated video with ffmpeg: freespecial5.mp4 (15 frames)
# Attempting to generate video using ffmpeg for freespecial6
# Generated video with ffmpeg: freespecial6.mp4 (20 frames)
# Attempting to generate video using ffmpeg for freespecial7
# Generated video with ffmpeg: freespecial7.mp4 (48 frames)
# Attempting to generate video using ffmpeg for follow4
# Generated video with ffmpeg: follow4.mp4 (65 frames)
# Attempting to generate video using ffmpeg for freespecial8
# Generated video with ffmpeg: freespecial8.mp4 (17 frames)
# Filling animation 'freespecial1' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for freespecial1
# Generated video with ffmpeg: freespecial1.mp4 (14 frames)
# Attempting to generate video using ffmpeg for follow1
# Generated video with ffmpeg: follow1.mp4 (118 frames)
# Attempting to generate video using ffmpeg for freespecial9
# Generated video with ffmpeg: freespecial9.mp4 (30 frames)
# Filling animation 'freespecial10' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for freespecial10
# Generated video with ffmpeg: freespecial10.mp4 (14 frames)
# Generated JSON summary: ryo_animations.json
#
# Animation generation completed successfully!
# Summary saved to: ryo_animations.json
#   2%|██████▉                                                                                                                                                                                                                                                                               | 1/40 [00:23<15:05, 23.22s/it]
# processing 1robert/robert.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 14 frames
# Filling animation 'waiting' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for waiting
# Generated video with ffmpeg: waiting.mp4 (14 frames)
# Attempting to generate video using ffmpeg for select
# Generated video with ffmpeg: select.mp4 (28 frames)
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (16 frames)
# Repeating animation 'idle' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (14 frames)
# Repeating animation 'walk' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (14 frames)
# Repeating animation 'run' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for run
# Generated video with ffmpeg: run.mp4 (14 frames)
# Attempting to generate video using ffmpeg for runattack
# Generated video with ffmpeg: runattack.mp4 (14 frames)
# Filling animation 'runjumpattack' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for runjumpattack
# Generated video with ffmpeg: runjumpattack.mp4 (14 frames)
# Filling animation 'block' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for block
# Generated video with ffmpeg: block.mp4 (14 frames)
# Filling animation 'attackup' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attackup
# Generated video with ffmpeg: attackup.mp4 (14 frames)
# Filling animation 'attackdown' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attackdown
# Generated video with ffmpeg: attackdown.mp4 (14 frames)
# Filling animation 'attack1' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack1
# Generated video with ffmpeg: attack1.mp4 (14 frames)
# Filling animation 'attack2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack2
# Generated video with ffmpeg: attack2.mp4 (14 frames)
# Filling animation 'attack3' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack3
# Generated video with ffmpeg: attack3.mp4 (14 frames)
# Filling animation 'attack4' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack4
# Generated video with ffmpeg: attack4.mp4 (14 frames)
# Filling animation 'attack5' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack5
# Generated video with ffmpeg: attack5.mp4 (14 frames)
# Filling animation 'attack6' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack6
# Generated video with ffmpeg: attack6.mp4 (14 frames)
# Filling animation 'attack7' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack7
# Generated video with ffmpeg: attack7.mp4 (14 frames)
# Attempting to generate video using ffmpeg for chargeattack
# Generated video with ffmpeg: chargeattack.mp4 (14 frames)
# Filling animation 'jumpdelay' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpdelay
# Generated video with ffmpeg: jumpdelay.mp4 (14 frames)
# Filling animation 'jumpland' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpland
# Generated video with ffmpeg: jumpland.mp4 (14 frames)
# Filling animation 'jump' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jump
# Generated video with ffmpeg: jump.mp4 (14 frames)
# Filling animation 'runjump' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for runjump
# Generated video with ffmpeg: runjump.mp4 (14 frames)
# Filling animation 'jumpattack' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpattack
# Generated video with ffmpeg: jumpattack.mp4 (14 frames)
# Filling animation 'jumpattack2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpattack2
# Generated video with ffmpeg: jumpattack2.mp4 (14 frames)
# Filling animation 'jumpattack3' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpattack3
# Generated video with ffmpeg: jumpattack3.mp4 (14 frames)
# Attempting to generate video using ffmpeg for special
# Generated video with ffmpeg: special.mp4 (21 frames)
# Filling animation 'charge' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for charge
# Generated video with ffmpeg: charge.mp4 (14 frames)
# Filling animation 'cant' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for cant
# Generated video with ffmpeg: cant.mp4 (14 frames)
# Attempting to generate video using ffmpeg for grab
# Generated video with ffmpeg: grab.mp4 (18 frames)
# Filling animation 'grabattack' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabattack
# Generated video with ffmpeg: grabattack.mp4 (14 frames)
# Filling animation 'grabforward' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabforward
# Generated video with ffmpeg: grabforward.mp4 (14 frames)
# Attempting to generate video using ffmpeg for grabattack2
# Generated video with ffmpeg: grabattack2.mp4 (18 frames)
# Filling animation 'grabforward2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabforward2
# Generated video with ffmpeg: grabforward2.mp4 (14 frames)
# Filling animation 'throw' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for throw
# Generated video with ffmpeg: throw.mp4 (14 frames)
# Attempting to generate video using ffmpeg for grabbed
# Generated video with ffmpeg: grabbed.mp4 (18 frames)
# Filling animation 'pain' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for pain
# Generated video with ffmpeg: pain.mp4 (14 frames)
# Filling animation 'pain2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for pain2
# Generated video with ffmpeg: pain2.mp4 (14 frames)
# Attempting to generate video using ffmpeg for pain3
# Generated video with ffmpeg: pain3.mp4 (19 frames)
# Attempting to generate video using ffmpeg for fall
# Generated video with ffmpeg: fall.mp4 (60 frames)
# Attempting to generate video using ffmpeg for fall2
# Generated video with ffmpeg: fall2.mp4 (60 frames)
# Attempting to generate video using ffmpeg for fall3
# Generated video with ffmpeg: fall3.mp4 (60 frames)
# Warning: Image not found: 1robert/burn1.gif
# Warning: Image not found: 1robert/burn2.gif
# Repeating animation 'burn' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for burn
# Generated video with ffmpeg: burn.mp4 (14 frames)
# Filling animation 'rise' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for rise
# Generated video with ffmpeg: rise.mp4 (14 frames)
# Attempting to generate video using ffmpeg for freespecial2
# Generated video with ffmpeg: freespecial2.mp4 (32 frames)
# Attempting to generate video using ffmpeg for follow2
# Generated video with ffmpeg: follow2.mp4 (19 frames)
# Attempting to generate video using ffmpeg for freespecial3
# Generated video with ffmpeg: freespecial3.mp4 (17 frames)
# Attempting to generate video using ffmpeg for freespecial4
# Generated video with ffmpeg: freespecial4.mp4 (16 frames)
# Attempting to generate video using ffmpeg for follow3
# Generated video with ffmpeg: follow3.mp4 (66 frames)
# Attempting to generate video using ffmpeg for freespecial5
# Generated video with ffmpeg: freespecial5.mp4 (15 frames)
# Attempting to generate video using ffmpeg for freespecial6
# Generated video with ffmpeg: freespecial6.mp4 (16 frames)
# Attempting to generate video using ffmpeg for freespecial7
# Generated video with ffmpeg: freespecial7.mp4 (47 frames)
# Attempting to generate video using ffmpeg for follow4
# Generated video with ffmpeg: follow4.mp4 (67 frames)
# Filling animation 'freespecial8' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for freespecial8
# Generated video with ffmpeg: freespecial8.mp4 (14 frames)
# Filling animation 'freespecial1' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for freespecial1
# Generated video with ffmpeg: freespecial1.mp4 (14 frames)
# Attempting to generate video using ffmpeg for follow1
# Generated video with ffmpeg: follow1.mp4 (109 frames)
# Attempting to generate video using ffmpeg for freespecial9
# Generated video with ffmpeg: freespecial9.mp4 (30 frames)
# Filling animation 'freespecial10' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for freespecial10
# Generated video with ffmpeg: freespecial10.mp4 (14 frames)
# Generated JSON summary: robert_animations.json
#
# Animation generation completed successfully!
# Summary saved to: robert_animations.json
#   5%|█████████████▉                                                                                                                                                                                                                                                                        | 2/40 [00:45<14:15, 22.51s/it]
# processing 1yuri/yuri.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 14 frames
# Filling animation 'waiting' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for waiting
# Generated video with ffmpeg: waiting.mp4 (14 frames)
# Attempting to generate video using ffmpeg for select
# Generated video with ffmpeg: select.mp4 (35 frames)
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (17 frames)
# Repeating animation 'idle' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (14 frames)
# Repeating animation 'walk' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (14 frames)
# Repeating animation 'run' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for run
# Generated video with ffmpeg: run.mp4 (14 frames)
# Attempting to generate video using ffmpeg for runattack
# Generated video with ffmpeg: runattack.mp4 (18 frames)
# Filling animation 'runjumpattack' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for runjumpattack
# Generated video with ffmpeg: runjumpattack.mp4 (14 frames)
# Filling animation 'block' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for block
# Generated video with ffmpeg: block.mp4 (14 frames)
# Filling animation 'attackup' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attackup
# Generated video with ffmpeg: attackup.mp4 (14 frames)
# Filling animation 'attackdown' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attackdown
# Generated video with ffmpeg: attackdown.mp4 (14 frames)
# Filling animation 'attack1' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack1
# Generated video with ffmpeg: attack1.mp4 (14 frames)
# Filling animation 'attack2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack2
# Generated video with ffmpeg: attack2.mp4 (14 frames)
# Filling animation 'attack3' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack3
# Generated video with ffmpeg: attack3.mp4 (14 frames)
# Filling animation 'attack4' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack4
# Generated video with ffmpeg: attack4.mp4 (14 frames)
# Attempting to generate video using ffmpeg for attack5
# Generated video with ffmpeg: attack5.mp4 (17 frames)
# Attempting to generate video using ffmpeg for chargeattack
# Generated video with ffmpeg: chargeattack.mp4 (14 frames)
# Filling animation 'jumpdelay' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpdelay
# Generated video with ffmpeg: jumpdelay.mp4 (14 frames)
# Filling animation 'jumpland' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpland
# Generated video with ffmpeg: jumpland.mp4 (14 frames)
# Filling animation 'jump' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jump
# Generated video with ffmpeg: jump.mp4 (14 frames)
# Filling animation 'runjump' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for runjump
# Generated video with ffmpeg: runjump.mp4 (14 frames)
# Filling animation 'jumpattack' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpattack
# Generated video with ffmpeg: jumpattack.mp4 (14 frames)
# Filling animation 'jumpattack2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpattack2
# Generated video with ffmpeg: jumpattack2.mp4 (14 frames)
# Filling animation 'jumpattack3' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpattack3
# Generated video with ffmpeg: jumpattack3.mp4 (14 frames)
# Filling animation 'follow5' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for follow5
# Generated video with ffmpeg: follow5.mp4 (14 frames)
# Filling animation 'special' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for special
# Generated video with ffmpeg: special.mp4 (14 frames)
# Filling animation 'charge' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for charge
# Generated video with ffmpeg: charge.mp4 (14 frames)
# Filling animation 'cant' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for cant
# Generated video with ffmpeg: cant.mp4 (14 frames)
# Attempting to generate video using ffmpeg for grab
# Generated video with ffmpeg: grab.mp4 (18 frames)
# Filling animation 'grabattack' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabattack
# Generated video with ffmpeg: grabattack.mp4 (14 frames)
# Filling animation 'grabforward' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabforward
# Generated video with ffmpeg: grabforward.mp4 (14 frames)
# Filling animation 'grabup' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabup
# Generated video with ffmpeg: grabup.mp4 (14 frames)
# Attempting to generate video using ffmpeg for grabattack2
# Generated video with ffmpeg: grabattack2.mp4 (18 frames)
# Filling animation 'grabforward2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabforward2
# Generated video with ffmpeg: grabforward2.mp4 (14 frames)
# Filling animation 'grabup2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabup2
# Generated video with ffmpeg: grabup2.mp4 (14 frames)
# Attempting to generate video using ffmpeg for throw
# Generated video with ffmpeg: throw.mp4 (18 frames)
# Attempting to generate video using ffmpeg for grabbed
# Generated video with ffmpeg: grabbed.mp4 (18 frames)
# Filling animation 'pain' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for pain
# Generated video with ffmpeg: pain.mp4 (14 frames)
# Filling animation 'pain2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for pain2
# Generated video with ffmpeg: pain2.mp4 (14 frames)
# Attempting to generate video using ffmpeg for pain3
# Generated video with ffmpeg: pain3.mp4 (19 frames)
# Attempting to generate video using ffmpeg for fall
# Generated video with ffmpeg: fall.mp4 (60 frames)
# Attempting to generate video using ffmpeg for fall2
# Generated video with ffmpeg: fall2.mp4 (60 frames)
# Attempting to generate video using ffmpeg for fall3
# Generated video with ffmpeg: fall3.mp4 (60 frames)
# Warning: Image not found: 1yuri/burn1.gif
# Warning: Image not found: 1yuri/burn2.gif
# Repeating animation 'burn' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for burn
# Generated video with ffmpeg: burn.mp4 (14 frames)
# Filling animation 'rise' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for rise
# Generated video with ffmpeg: rise.mp4 (14 frames)
# Attempting to generate video using ffmpeg for freespecial2
# Generated video with ffmpeg: freespecial2.mp4 (18 frames)
# Attempting to generate video using ffmpeg for freespecial3
# Generated video with ffmpeg: freespecial3.mp4 (21 frames)
# Attempting to generate video using ffmpeg for freespecial4
# Generated video with ffmpeg: freespecial4.mp4 (18 frames)
# Attempting to generate video using ffmpeg for follow2
# Generated video with ffmpeg: follow2.mp4 (19 frames)
# Filling animation 'freespecial5' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for freespecial5
# Generated video with ffmpeg: freespecial5.mp4 (14 frames)
# Attempting to generate video using ffmpeg for freespecial6
# Generated video with ffmpeg: freespecial6.mp4 (19 frames)
# Attempting to generate video using ffmpeg for freespecial7
# Generated video with ffmpeg: freespecial7.mp4 (45 frames)
# Attempting to generate video using ffmpeg for follow3
# Generated video with ffmpeg: follow3.mp4 (62 frames)
# Attempting to generate video using ffmpeg for freespecial8
# Generated video with ffmpeg: freespecial8.mp4 (17 frames)
# Filling animation 'freespecial1' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for freespecial1
# Generated video with ffmpeg: freespecial1.mp4 (14 frames)
# Attempting to generate video using ffmpeg for follow1
# Generated video with ffmpeg: follow1.mp4 (88 frames)
# Attempting to generate video using ffmpeg for freespecial9
# Generated video with ffmpeg: freespecial9.mp4 (23 frames)
# Attempting to generate video using ffmpeg for freespecial10
# Generated video with ffmpeg: freespecial10.mp4 (17 frames)
# Generated JSON summary: yuri_animations.json
#
# Animation generation completed successfully!
# Summary saved to: yuri_animations.json
#   8%|████████████████████▊                                                                                                                                                                                                                                                                 | 3/40 [01:05<13:22, 21.69s/it]
# processing fterry/terry.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 14 frames
# Filling animation 'waiting' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for waiting
# Generated video with ffmpeg: waiting.mp4 (14 frames)
# Attempting to generate video using ffmpeg for select
# Generated video with ffmpeg: select.mp4 (22 frames)
# Filling animation 'spawn' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (14 frames)
# Repeating animation 'idle' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (14 frames)
# Repeating animation 'walk' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (14 frames)
# Repeating animation 'run' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for run
# Generated video with ffmpeg: run.mp4 (14 frames)
# Attempting to generate video using ffmpeg for runattack
# Generated video with ffmpeg: runattack.mp4 (28 frames)
# Filling animation 'runjumpattack' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for runjumpattack
# Generated video with ffmpeg: runjumpattack.mp4 (14 frames)
# Filling animation 'block' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for block
# Generated video with ffmpeg: block.mp4 (14 frames)
# Filling animation 'attackup' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attackup
# Generated video with ffmpeg: attackup.mp4 (14 frames)
# Filling animation 'attackdown' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attackdown
# Generated video with ffmpeg: attackdown.mp4 (14 frames)
# Filling animation 'attack1' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack1
# Generated video with ffmpeg: attack1.mp4 (14 frames)
# Filling animation 'attack2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack2
# Generated video with ffmpeg: attack2.mp4 (14 frames)
# Filling animation 'attack3' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack3
# Generated video with ffmpeg: attack3.mp4 (14 frames)
# Filling animation 'attack4' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack4
# Generated video with ffmpeg: attack4.mp4 (14 frames)
# Filling animation 'attack5' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack5
# Generated video with ffmpeg: attack5.mp4 (14 frames)
# Filling animation 'attack6' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack6
# Generated video with ffmpeg: attack6.mp4 (14 frames)
# Filling animation 'attack7' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack7
# Generated video with ffmpeg: attack7.mp4 (14 frames)
# Attempting to generate video using ffmpeg for chargeattack
# Generated video with ffmpeg: chargeattack.mp4 (15 frames)
# Filling animation 'jumpdelay' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpdelay
# Generated video with ffmpeg: jumpdelay.mp4 (14 frames)
# Filling animation 'jumpland' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpland
# Generated video with ffmpeg: jumpland.mp4 (14 frames)
# Filling animation 'jump' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jump
# Generated video with ffmpeg: jump.mp4 (14 frames)
# Filling animation 'runjump' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for runjump
# Generated video with ffmpeg: runjump.mp4 (14 frames)
# Filling animation 'jumpattack' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpattack
# Generated video with ffmpeg: jumpattack.mp4 (14 frames)
# Filling animation 'jumpattack2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpattack2
# Generated video with ffmpeg: jumpattack2.mp4 (14 frames)
# Attempting to generate video using ffmpeg for special
# Generated video with ffmpeg: special.mp4 (18 frames)
# Filling animation 'charge' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for charge
# Generated video with ffmpeg: charge.mp4 (14 frames)
# Filling animation 'cant' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for cant
# Generated video with ffmpeg: cant.mp4 (14 frames)
# Attempting to generate video using ffmpeg for grab
# Generated video with ffmpeg: grab.mp4 (18 frames)
# Filling animation 'grabattack' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabattack
# Generated video with ffmpeg: grabattack.mp4 (14 frames)
# Filling animation 'grabforward' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabforward
# Generated video with ffmpeg: grabforward.mp4 (14 frames)
# Attempting to generate video using ffmpeg for grabattack2
# Generated video with ffmpeg: grabattack2.mp4 (16 frames)
# Attempting to generate video using ffmpeg for grabforward2
# Generated video with ffmpeg: grabforward2.mp4 (22 frames)
# Filling animation 'throw' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for throw
# Generated video with ffmpeg: throw.mp4 (14 frames)
# Attempting to generate video using ffmpeg for grabbed
# Generated video with ffmpeg: grabbed.mp4 (18 frames)
# Filling animation 'pain' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for pain
# Generated video with ffmpeg: pain.mp4 (14 frames)
# Filling animation 'pain2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for pain2
# Generated video with ffmpeg: pain2.mp4 (14 frames)
# Attempting to generate video using ffmpeg for pain3
# Generated video with ffmpeg: pain3.mp4 (19 frames)
# Attempting to generate video using ffmpeg for fall
# Generated video with ffmpeg: fall.mp4 (60 frames)
# Attempting to generate video using ffmpeg for fall2
# Generated video with ffmpeg: fall2.mp4 (60 frames)
# Attempting to generate video using ffmpeg for fall3
# Generated video with ffmpeg: fall3.mp4 (60 frames)
# Warning: Image not found: fterry/burn1.gif
# Warning: Image not found: fterry/burn2.gif
# Repeating animation 'burn' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for burn
# Generated video with ffmpeg: burn.mp4 (14 frames)
# Filling animation 'rise' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for rise
# Generated video with ffmpeg: rise.mp4 (14 frames)
# Attempting to generate video using ffmpeg for freespecial2
# Generated video with ffmpeg: freespecial2.mp4 (19 frames)
# Attempting to generate video using ffmpeg for freespecial3
# Generated video with ffmpeg: freespecial3.mp4 (27 frames)
# Attempting to generate video using ffmpeg for freespecial4
# Generated video with ffmpeg: freespecial4.mp4 (19 frames)
# Filling animation 'freespecial5' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for freespecial5
# Generated video with ffmpeg: freespecial5.mp4 (14 frames)
# Attempting to generate video using ffmpeg for freespecial6
# Generated video with ffmpeg: freespecial6.mp4 (15 frames)
# Attempting to generate video using ffmpeg for freespecial7
# Generated video with ffmpeg: freespecial7.mp4 (47 frames)
# Filling animation 'freespecial8' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for freespecial8
# Generated video with ffmpeg: freespecial8.mp4 (14 frames)
# Filling animation 'freespecial1' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for freespecial1
# Generated video with ffmpeg: freespecial1.mp4 (14 frames)
# Attempting to generate video using ffmpeg for follow1
# Generated video with ffmpeg: follow1.mp4 (77 frames)
# Generated JSON summary: terry_animations.json
#
# Animation generation completed successfully!
# Summary saved to: terry_animations.json
#  10%|███████████████████████████▊                                                                                                                                                                                                                                                          | 4/40 [01:24<12:11, 20.32s/it]
# processing fandy/andy.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 14 frames
# Filling animation 'waiting' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for waiting
# Generated video with ffmpeg: waiting.mp4 (14 frames)
# Attempting to generate video using ffmpeg for select
# Generated video with ffmpeg: select.mp4 (24 frames)
# Filling animation 'spawn' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (14 frames)
# Repeating animation 'idle' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (14 frames)
# Repeating animation 'walk' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (14 frames)
# Repeating animation 'run' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for run
# Generated video with ffmpeg: run.mp4 (14 frames)
# Filling animation 'runjumpattack' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for runjumpattack
# Generated video with ffmpeg: runjumpattack.mp4 (14 frames)
# Filling animation 'block' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for block
# Generated video with ffmpeg: block.mp4 (14 frames)
# Filling animation 'attackup' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attackup
# Generated video with ffmpeg: attackup.mp4 (14 frames)
# Filling animation 'attackdown' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attackdown
# Generated video with ffmpeg: attackdown.mp4 (14 frames)
# Filling animation 'attack1' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack1
# Generated video with ffmpeg: attack1.mp4 (14 frames)
# Filling animation 'attack2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack2
# Generated video with ffmpeg: attack2.mp4 (14 frames)
# Filling animation 'attack3' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack3
# Generated video with ffmpeg: attack3.mp4 (14 frames)
# Filling animation 'attack4' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack4
# Generated video with ffmpeg: attack4.mp4 (14 frames)
# Filling animation 'attack5' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack5
# Generated video with ffmpeg: attack5.mp4 (14 frames)
# Filling animation 'chargeattack' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for chargeattack
# Generated video with ffmpeg: chargeattack.mp4 (14 frames)
# Filling animation 'jumpdelay' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpdelay
# Generated video with ffmpeg: jumpdelay.mp4 (14 frames)
# Filling animation 'jumpland' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpland
# Generated video with ffmpeg: jumpland.mp4 (14 frames)
# Filling animation 'jump' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jump
# Generated video with ffmpeg: jump.mp4 (14 frames)
# Filling animation 'runjump' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for runjump
# Generated video with ffmpeg: runjump.mp4 (14 frames)
# Filling animation 'jumpattack' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpattack
# Generated video with ffmpeg: jumpattack.mp4 (14 frames)
# Filling animation 'jumpattack2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for jumpattack2
# Generated video with ffmpeg: jumpattack2.mp4 (14 frames)
# Attempting to generate video using ffmpeg for special
# Generated video with ffmpeg: special.mp4 (21 frames)
# Filling animation 'charge' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for charge
# Generated video with ffmpeg: charge.mp4 (14 frames)
# Filling animation 'cant' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for cant
# Generated video with ffmpeg: cant.mp4 (14 frames)
# Attempting to generate video using ffmpeg for grab
# Generated video with ffmpeg: grab.mp4 (18 frames)
# Filling animation 'grabattack' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabattack
# Generated video with ffmpeg: grabattack.mp4 (14 frames)
# Filling animation 'grabforward' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabforward
# Generated video with ffmpeg: grabforward.mp4 (14 frames)
# Filling animation 'grabattack2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabattack2
# Generated video with ffmpeg: grabattack2.mp4 (14 frames)
# Filling animation 'grabforward2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabforward2
# Generated video with ffmpeg: grabforward2.mp4 (14 frames)
# Filling animation 'grabup' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabup
# Generated video with ffmpeg: grabup.mp4 (14 frames)
# Attempting to generate video using ffmpeg for follow2
# Generated video with ffmpeg: follow2.mp4 (42 frames)
# Filling animation 'throw' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for throw
# Generated video with ffmpeg: throw.mp4 (14 frames)
# Attempting to generate video using ffmpeg for grabbed
# Generated video with ffmpeg: grabbed.mp4 (18 frames)
# Filling animation 'pain' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for pain
# Generated video with ffmpeg: pain.mp4 (14 frames)
# Filling animation 'pain2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for pain2
# Generated video with ffmpeg: pain2.mp4 (14 frames)
# Attempting to generate video using ffmpeg for pain3
# Generated video with ffmpeg: pain3.mp4 (19 frames)
# Attempting to generate video using ffmpeg for fall
# Generated video with ffmpeg: fall.mp4 (60 frames)
# Attempting to generate video using ffmpeg for fall2
# Generated video with ffmpeg: fall2.mp4 (60 frames)
# Attempting to generate video using ffmpeg for fall3
# Generated video with ffmpeg: fall3.mp4 (60 frames)
# Warning: Image not found: fandy/burn1.gif
# Warning: Image not found: fandy/burn2.gif
# Repeating animation 'burn' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for burn
# Generated video with ffmpeg: burn.mp4 (14 frames)
# Filling animation 'rise' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for rise
# Generated video with ffmpeg: rise.mp4 (14 frames)
# Attempting to generate video using ffmpeg for freespecial2
# Generated video with ffmpeg: freespecial2.mp4 (15 frames)
# Attempting to generate video using ffmpeg for freespecial3
# Generated video with ffmpeg: freespecial3.mp4 (22 frames)
# Attempting to generate video using ffmpeg for freespecial4
# Generated video with ffmpeg: freespecial4.mp4 (24 frames)
# Filling animation 'follow3' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for follow3
# Generated video with ffmpeg: follow3.mp4 (14 frames)
# Attempting to generate video using ffmpeg for freespecial5
# Generated video with ffmpeg: freespecial5.mp4 (14 frames)
# Attempting to generate video using ffmpeg for freespecial6
# Generated video with ffmpeg: freespecial6.mp4 (49 frames)
# Attempting to generate video using ffmpeg for freespecial7
# Generated video with ffmpeg: freespecial7.mp4 (20 frames)
# Filling animation 'freespecial1' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for freespecial1
# Generated video with ffmpeg: freespecial1.mp4 (14 frames)
# Attempting to generate video using ffmpeg for follow1
# Generated video with ffmpeg: follow1.mp4 (246 frames)
# Attempting to generate video using ffmpeg for freespecial8
# Generated video with ffmpeg: freespecial8.mp4 (32 frames)
# Filling animation 'freespecial9' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for freespecial9
# Generated video with ffmpeg: freespecial9.mp4 (14 frames)
# Generated JSON summary: andy_animations.json
#
# Animation generation completed successfully!
# Summary saved to: andy_animations.json
#  12%|██████████████████████████████████▊                                                                                                                                                                                                                                                   | 5/40 [01:43<11:38, 19.97s/it]
# processing fjoe/joe.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 14 frames
# Filling animation 'waiting' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for waiting
# Generated video with ffmpeg: waiting.mp4 (14 frames)
# Attempting to generate video using ffmpeg for select
# Generated video with ffmpeg: select.mp4 (25 frames)
# Filling animation 'spawn' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (14 frames)
# Repeating animation 'idle' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (14 frames)
# Repeating animation 'walk' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (14 frames)
# Repeating animation 'run' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for run
# Generated video with ffmpeg: run.mp4 (14 frames)
# ...
# Filling animation 'death' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for death
# Generated video with ffmpeg: death.mp4 (14 frames)
# Generated JSON summary: sold2_animations.json
#
# Animation generation completed successfully!
# Summary saved to: sold2_animations.json
#  82%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                | 33/40 [06:30<01:07,  9.66s/it]
# processing 2sold3/sold3.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 14 frames
# Filling animation 'spawn' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (14 frames)
# Repeating animation 'idle' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (14 frames)
# Repeating animation 'walk' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (14 frames)
# Filling animation 'attack1' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack1
# Generated video with ffmpeg: attack1.mp4 (14 frames)
# Attempting to generate video using ffmpeg for attack2
# Generated video with ffmpeg: attack2.mp4 (27 frames)
# Attempting to generate video using ffmpeg for attack3
# Generated video with ffmpeg: attack3.mp4 (15 frames)
# Attempting to generate video using ffmpeg for riseattack
# Generated video with ffmpeg: riseattack.mp4 (27 frames)
# Filling animation 'grabbed' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabbed
# Generated video with ffmpeg: grabbed.mp4 (14 frames)
# Filling animation 'pain' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for pain
# Generated video with ffmpeg: pain.mp4 (14 frames)
# Filling animation 'pain2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for pain2
# Generated video with ffmpeg: pain2.mp4 (14 frames)
# Attempting to generate video using ffmpeg for pain3
# Generated video with ffmpeg: pain3.mp4 (17 frames)
# Attempting to generate video using ffmpeg for pain4
# Generated video with ffmpeg: pain4.mp4 (26 frames)
# Filling animation 'pain5' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for pain5
# Generated video with ffmpeg: pain5.mp4 (14 frames)
# Filling animation 'pain6' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for pain6
# Generated video with ffmpeg: pain6.mp4 (14 frames)
# Attempting to generate video using ffmpeg for pain7
# Generated video with ffmpeg: pain7.mp4 (39 frames)
# Attempting to generate video using ffmpeg for pain8
# Generated video with ffmpeg: pain8.mp4 (16 frames)
# Attempting to generate video using ffmpeg for pain9
# Generated video with ffmpeg: pain9.mp4 (28 frames)
# Filling animation 'fall' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for fall
# Generated video with ffmpeg: fall.mp4 (14 frames)
# Filling animation 'fall2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for fall2
# Generated video with ffmpeg: fall2.mp4 (14 frames)
# Attempting to generate video using ffmpeg for fall7
# Generated video with ffmpeg: fall7.mp4 (334 frames)
# Filling animation 'fall9' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for fall9
# Generated video with ffmpeg: fall9.mp4 (14 frames)
# Warning: Image not found: 2sold3/burn1.gif
# Warning: Image not found: 2sold3/burn2.gif
# Repeating animation 'burn' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for burn
# Generated video with ffmpeg: burn.mp4 (14 frames)
# Attempting to generate video using ffmpeg for rise
# Generated video with ffmpeg: rise.mp4 (20 frames)
# Filling animation 'death' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for death
# Generated video with ffmpeg: death.mp4 (14 frames)
# Generated JSON summary: sold3_animations.json
#
# Animation generation completed successfully!
# Summary saved to: sold3_animations.json
#  85%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                         | 34/40 [06:38<00:55,  9.27s/it]
# processing 4bike2/ghost1.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 14 frames
# Warning: Image not found: 4bike2/empty.gif
# Warning: Image not found: 4bike2/empty.gif
# Filling animation 'spawn' with idle frames to reach 14 frames (loop=0)
# Warning: Image not found: 4bike2/empty.gif
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (14 frames)
# Warning: Image not found: 4bike2/empty.gif
# Warning: Image not found: 4bike2/empty.gif
# Filling animation 'idle' with idle frames to reach 14 frames (loop=0)
# Warning: Image not found: 4bike2/empty.gif
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (14 frames)
# Warning: Image not found: 4bike2/empty.gif
# Warning: Image not found: 4bike2/empty.gif
# Filling animation 'walk' with idle frames to reach 14 frames (loop=0)
# Warning: Image not found: 4bike2/empty.gif
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (14 frames)
# Generated JSON summary: ghost1_animations.json
#
# Animation generation completed successfully!
# Summary saved to: ghost1_animations.json
#  88%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                  | 35/40 [06:39<00:33,  6.78s/it]
# processing 4bike2/ghost2.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 14 frames
# Warning: Image not found: 4bike2/empty.gif
# Warning: Image not found: 4bike2/empty.gif
# Filling animation 'spawn' with idle frames to reach 14 frames (loop=0)
# Warning: Image not found: 4bike2/empty.gif
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (14 frames)
# Warning: Image not found: 4bike2/empty.gif
# Warning: Image not found: 4bike2/empty.gif
# Filling animation 'idle' with idle frames to reach 14 frames (loop=0)
# Warning: Image not found: 4bike2/empty.gif
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (14 frames)
# Warning: Image not found: 4bike2/empty.gif
# Warning: Image not found: 4bike2/empty.gif
# Filling animation 'walk' with idle frames to reach 14 frames (loop=0)
# Warning: Image not found: 4bike2/empty.gif
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (14 frames)
# Generated JSON summary: ghost2_animations.json
#
# Animation generation completed successfully!
# Summary saved to: ghost2_animations.json
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                           | 36/40 [06:40<00:20,  5.05s/it]
# processing 4bike2/ghost3.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 14 frames
# Warning: Image not found: 4bike2/empty.gif
# Warning: Image not found: 4bike2/empty.gif
# Filling animation 'spawn' with idle frames to reach 14 frames (loop=0)
# Warning: Image not found: 4bike2/empty.gif
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (14 frames)
# Warning: Image not found: 4bike2/empty.gif
# Warning: Image not found: 4bike2/empty.gif
# Filling animation 'idle' with idle frames to reach 14 frames (loop=0)
# Warning: Image not found: 4bike2/empty.gif
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (14 frames)
# Warning: Image not found: 4bike2/empty.gif
# Warning: Image not found: 4bike2/empty.gif
# Filling animation 'walk' with idle frames to reach 14 frames (loop=0)
# Warning: Image not found: 4bike2/empty.gif
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (14 frames)
# Generated JSON summary: ghost3_animations.json
#
# Animation generation completed successfully!
# Summary saved to: ghost3_animations.json
#  92%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                    | 37/40 [06:41<00:11,  3.83s/it]
# processing 5geese/geese.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 14 frames
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (113 frames)
# Attempting to generate video using ffmpeg for block
# Generated video with ffmpeg: block.mp4 (42 frames)
# Repeating animation 'idle' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (14 frames)
# Repeating animation 'walk' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (14 frames)
# Repeating animation 'run' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for run
# Generated video with ffmpeg: run.mp4 (14 frames)
# Repeating animation 'attack1' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for attack1
# Generated video with ffmpeg: attack1.mp4 (14 frames)
# Attempting to generate video using ffmpeg for follow1
# Generated video with ffmpeg: follow1.mp4 (15 frames)
# Attempting to generate video using ffmpeg for attack2
# Generated video with ffmpeg: attack2.mp4 (33 frames)
# Attempting to generate video using ffmpeg for attack3
# Generated video with ffmpeg: attack3.mp4 (24 frames)
# Attempting to generate video using ffmpeg for attack4
# Generated video with ffmpeg: attack4.mp4 (14 frames)
# Attempting to generate video using ffmpeg for attack5
# Generated video with ffmpeg: attack5.mp4 (14 frames)
# Attempting to generate video using ffmpeg for attack6
# Generated video with ffmpeg: attack6.mp4 (21 frames)
# Attempting to generate video using ffmpeg for riseattack
# Generated video with ffmpeg: riseattack.mp4 (24 frames)
# Attempting to generate video using ffmpeg for upper
# Generated video with ffmpeg: upper.mp4 (18 frames)
# Filling animation 'grabbed' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for grabbed
# Generated video with ffmpeg: grabbed.mp4 (14 frames)
# Filling animation 'pain' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for pain
# Generated video with ffmpeg: pain.mp4 (14 frames)
# Filling animation 'pain2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for pain2
# Generated video with ffmpeg: pain2.mp4 (14 frames)
# Attempting to generate video using ffmpeg for pain3
# Generated video with ffmpeg: pain3.mp4 (17 frames)
# Attempting to generate video using ffmpeg for pain4
# Generated video with ffmpeg: pain4.mp4 (26 frames)
# Filling animation 'pain5' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for pain5
# Generated video with ffmpeg: pain5.mp4 (14 frames)
# Filling animation 'pain6' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for pain6
# Generated video with ffmpeg: pain6.mp4 (14 frames)
# Attempting to generate video using ffmpeg for pain7
# Generated video with ffmpeg: pain7.mp4 (39 frames)
# Attempting to generate video using ffmpeg for pain8
# Generated video with ffmpeg: pain8.mp4 (16 frames)
# Attempting to generate video using ffmpeg for pain9
# Generated video with ffmpeg: pain9.mp4 (28 frames)
# Filling animation 'fall' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for fall
# Generated video with ffmpeg: fall.mp4 (14 frames)
# Filling animation 'fall2' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for fall2
# Generated video with ffmpeg: fall2.mp4 (14 frames)
# Attempting to generate video using ffmpeg for fall7
# Generated video with ffmpeg: fall7.mp4 (334 frames)
# Filling animation 'fall9' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for fall9
# Generated video with ffmpeg: fall9.mp4 (14 frames)
# Warning: Image not found: 5geese/burn1.gif
# Warning: Image not found: 5geese/burn2.gif
# Repeating animation 'burn' to reach 14 frames (loop=1)
# Attempting to generate video using ffmpeg for burn
# Generated video with ffmpeg: burn.mp4 (14 frames)
# Filling animation 'rise' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for rise
# Generated video with ffmpeg: rise.mp4 (14 frames)
# Warning: Image not found: 5geese/empty.gif
# Attempting to generate video using ffmpeg for death
# Generated video with ffmpeg: death.mp4 (81 frames)
# Generated JSON summary: geese_animations.json
#
# Animation generation completed successfully!
# Summary saved to: geese_animations.json
#  95%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏             | 38/40 [06:53<00:12,  6.15s/it]
# processing 5geese/geesed.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 14 frames
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (152 frames)
# Warning: Image not found: 5geese/empty.gif
# Filling animation 'walk' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (14 frames)
# Warning: Image not found: 5geese/empty.gif
# Filling animation 'attack' with idle frames to reach 14 frames (loop=0)
# Attempting to generate video using ffmpeg for attack
# Generated video with ffmpeg: attack.mp4 (14 frames)
# Generated JSON summary: geesed_animations.json
#
# Animation generation completed successfully!
# Summary saved to: geesed_animations.json
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████       | 39/40 [06:54<00:04,  4.75s/it]
# processing 5geese/gagent.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 14 frames
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (39 frames)
# Generated JSON summary: gagent_animations.json
#
# Animation generation completed successfully!
# Summary saved to: gagent_animations.json
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 40/40 [06:55<00:00, 10.39s/it]

# %% [markdown]
# # gather animation videos by type

# %%
target_path = '/Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos'

# %%
import glob
from tqdm import tqdm
import os, json

all_animations = set()

for chdir in tqdm(chars):
    json_file = chdir.replace(".txt", "_animations.json")
    if not os.path.exists(json_file):
        print("not found")
    with open(json_file, 'r') as jf:
        videos = json.load(jf)
    for l in videos:
        all_animations.add(l['animation'])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 40/40 [00:00<00:00, 3031.28it/s]

# %%
for ani in all_animations:
    # !mkdir -p {target_path}/{ani}

# %%
import uuid

# Generate a version 4 UUID (random)
random_uuid = uuid.uuid4()
random_uuid, str(random_uuid)[-8:]
# Out:
# (UUID('1287217e-e900-43e8-8e99-d8f524c37f04'), '24c37f04')

# %%
import shutil
from pathlib import Path
animation_to_info = {}

for chdir in tqdm(chars):
    json_file = chdir.replace(".txt", "_animations.json")
    if not os.path.exists(json_file):
        print("not found")
    with open(json_file, 'r') as jf:
        videos = json.load(jf)
    for l in videos:
        #all_animations.add(l['animation'])
        source_file = f"{os.path.dirname(chdir)}/{l['video']}"
        p = Path(chdir)
        char_name = p.name.split(".")[0]
        
        # Generate a version 4 UUID (random)
        random_uuid = uuid.uuid4()
        random_uuid = str(random_uuid)[-8:]

        shutil.copy(source_file, f"{target_path}/{l['animation']}/{char_name}_{random_uuid}.mp4")
        
        if l['animation'] not in animation_to_info:
            animation_to_info[l['animation']] = []
        ll = l.copy()
        ll['video'] = f"{char_name}_{random_uuid}.mp4"
        animation_to_info[l['animation']].append(ll)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 40/40 [00:00<00:00, 75.74it/s]

# %%
animation_to_info

with open(f"{target_path}/info.json", 'w') as f:
    json.dump(animation_to_info, f)

# %%
import os
os.environ["GEMINI_API_KEY"] = ""

os.environ["GEMINI_API_KEY"]
# Out:
# 'AIzaSyAxyUUUs5zFnqj33E0kQ_eijZkcgv7BBXo'

# %%
from google import genai
from google.genai import types


client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])



#video_file_name = "/Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/terry.mp4"
#video_bytes = open(video_file_name, 'rb').read()

# %%
TEST=False

if TEST:
    myfile = client.files.upload(file=video_file_name)


    prompt = "Given this gaming animation of a character walking in side view with solid color background, describe the video. describe the character in detail and the action the character is doing. Don't go beyond 230 words."


    response = client.models.generate_content(
        model="gemini-2.5-pro-preview-05-06", 
        contents=[myfile, prompt]
        #contents=types.Content(
        #    parts=[
        #        genai.types.Part(
        #            inline_data=types.Blob(data=video_bytes, 
        #                                   mime_type='video/mp4',
        #                                   #video_metadata=genai.types.VideoMetadata(start_offset='0s', fps=16)
        #                                  )
        #        ),
        #        genai.types.Part(text=prompt)
        #    ]
        #)
    )

    print(response.text)
# Out:
# This video showcases a 2D pixel art animation of a character, likely from a classic fighting game, walking from left to right. The background is a solid, bright cyan, which ensures the character stands out.
#
# The character depicted is a muscular male with a confident posture. He sports a red baseball cap with a white front panel, worn backwards, revealing some of his blonde hair. He's dressed in a sleeveless, open red vest over a white undershirt, dark blue denim jeans, and red and white sneakers. His hands are covered in red fingerless gloves, and he maintains clenched fists as he walks.
#
# His action consists of a continuous walk cycle. The animation is smooth, with a characteristic bouncy rhythm often seen in 2D sprite-based fighting games. His arms swing naturally in opposition to his leg movements, conveying a sense of purpose and readiness as he traverses the screen.

# %%
import time
time.sleep(2)

# %%
def get_video_prompt(video_path, animation):
    print(f"uploading {video_path}, {os.path.isfile(video_path)}, {os.fspath(video_path)}")
    myfile = client.files.upload(file=video_path)
    time.sleep(2)


    prompt = f"Given this gaming {animation} animation of a character in side view with solid color background, we want to generate a video generation prompt that can be used to generate this video. In the prompt, describe the character in detail and the action the character is doing. Don't go beyond 230 words. Only output the prompt, nothing else."

    RETRY = 5
    for i in range(RETRY):
        try:
            response = client.models.generate_content(
                model="gemini-2.5-pro-preview-05-06", 
                contents=[myfile, prompt]
            )
            break
        except Excption as e:
            print(f"error: {e}")
            time.sleep(2)
    return response.text

# %%
if True:
    get_video_prompt("/Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/lee_8d66d866.mp4", 'walk')
# Out:
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/lee_8d66d866.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/lee_8d66d866.mp4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 if True:
# ----> 2     get_video_prompt("/Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/lee_8d66d866.mp4", 'walk')
#
# Cell In[5], line 4, in get_video_prompt(video_path, animation)
#       2 print(f"uploading {video_path}, {os.path.isfile(video_path)}, {os.fspath(video_path)}")
#       3 myfile = client.files.upload(file=video_path)
# ----> 4 time.sleep(2)
#       7 prompt = f"Given this gaming {animation} animation of a character in side view with solid color background, we want to generate a video generation prompt that can be used to generate this video. In the prompt, describe the character in detail and the action the character is doing. Don't go beyond 230 words. Only output the prompt, nothing else."
#       9 RETRY = 5
#
# NameError: name 'time' is not defined

# %% [markdown]
# # gen prompt for walking

# %%
from tqdm import tqdm
import glob

for f in tqdm(glob.glob(f"{target_path}/walk/*.mp4")):
    print(f"processing {f}")
    prompt = get_video_prompt(f, 'walk')
    print(f"gend prompt for {f}:\n {prompt}")
    #p = Path(f)
    pfn = f.replace(".mp4", ".txt")
    
    tag_word = "game animation walk,"
    
    with open(pfn, 'w') as pf:
        pf.write(f"{tag_word} {prompt}")
# Out:
#   0%|                                                                                                                                                                                                                                                                                              | 0/34 [00:00<?, ?it/s]
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/lee_8d66d866.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/lee_8d66d866.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/lee_8d66d866.mp4
#   3%|████████▏                                                                                                                                                                                                                                                                             | 1/34 [00:31<17:14, 31.35s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/lee_8d66d866.mp4:
#  A 2D pixel art animation of a male martial arts master walking, presented in a side view. He has white hair, styled tied back or in a topknot, and wears a distinctive green mask covering his eyes and upper face. His attire features a black, sleeveless vest-like garment with subtle gold trim, worn over a white long-sleeved undershirt. A long, flowing white open-front robe with a thick black border drapes over his shoulders, reaching mid-calf. He sports voluminous white baggy pants, neatly tucked into black martial arts shoes.
#
# The character performs a fluid walking animation, moving with a confident gait from one side of the frame to the other, or as a continuous loop. His arms swing rhythmically in opposition to his legs, and his hands are held in a relaxed but ready martial arts posture, slightly clenched. The animation style is crisp pixel art, reminiscent of classic 2D fighting game sprites from the 1990s, with clear, distinct frames making up the walk cycle. The background is a solid, vibrant cyan. The walk cycle should be smooth and convey a sense of controlled movement and readiness.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/punk2_84a741e2.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/punk2_84a741e2.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/punk2_84a741e2.mp4
#   6%|████████████████▎                                                                                                                                                                                                                                                                     | 2/34 [00:51<13:11, 24.72s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/punk2_84a741e2.mp4:
#  A 2D pixel art animation of a young male character with an urban fighter aesthetic. He has short, spiky black hair and a determined expression. He wears a tight-fitting black or very dark grey short-sleeved top with a distinctive diagonal silver strap detail across the chest, paired with matching dark, slightly flared pants. A prominent silver-buckled belt cinches his waist. He sports black fingerless gloves and white athletic shoes with dark soles.
#
# The character is performing a smooth, confident walk cycle, viewed from a side profile. His arms swing rhythmically, and there's a slight swagger in his gait as he strides forward. The background is a solid, vibrant cyan. The overall style is reminiscent of classic 2D fighting game sprite animations.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/king2_4a1667dd.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/king2_4a1667dd.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/king2_4a1667dd.mp4
#   9%|████████████████████████▌                                                                                                                                                                                                                                                             | 3/34 [01:08<10:57, 21.20s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/king2_4a1667dd.mp4:
#  Pixel art animation of a slender, dapper man with short, slicked-back blonde hair. He wears a rich maroon, cropped bolero-style jacket with prominent white rolled-up cuffs, over matching maroon trousers. White gloves and dark, possibly black, dress shoes complete his ensemble.
#
# He performs a smooth, slightly flamboyant walking animation cycle, moving from right to left across the screen. His arms swing rhythmically, with hands held somewhat high, suggesting readiness or a confident swagger. His legs move with a distinct, stylized gait.
#
# The style is retro 2D fighting game sprite animation. The perspective is a clear side-view. The background is a flat, vibrant solid cyan. The animation should loop seamlessly, capturing a classic gaming walk cycle.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/yuri_b69a780a.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/yuri_b69a780a.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/yuri_b69a780a.mp4
#  12%|████████████████████████████████▋                                                                                                                                                                                                                                                     | 4/34 [01:28<10:18, 20.63s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/yuri_b69a780a.mp4:
#  Pixel art animation, 16-bit retro arcade style. An athletic female character with long, dark brown hair tied back, possibly in a ponytail. She wears a loose-fitting white top or t-shirt, perhaps with a small, subtle emblem on the chest, tucked slightly or short. Her bottoms are striking purple athletic leggings, and she sports red and white trainers. A dark-colored jacket or shirt is tied around her waist, its ends hanging loosely.
#
# She performs a fluid, looping side-view walk animation cycle, moving with purpose. Her arms are bent, fists lightly clenched, suggesting a ready or determined stance as she paces. The background is a solid, bright cyan. The overall aesthetic should be reminiscent of a classic 2D fighting game character sprite from the 90s.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/punk3_9b070235.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/punk3_9b070235.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/punk3_9b070235.mp4
#  15%|████████████████████████████████████████▉                                                                                                                                                                                                                                             | 5/34 [01:56<11:20, 23.45s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/punk3_9b070235.mp4:
#  Generate a 2D pixel art sprite animation of a male character in a side view, executing a walking cycle.
# The character has medium-length, styled black hair. He wears a distinctive long, royal blue trench coat with prominent wide lapels and a slightly raised collar, worn open. This coat, appearing to be of a substantial fabric, sways subtly with his motion. Underneath the coat, he sports a black long-sleeved shirt, visible at the cuffs, complemented by dark grey or black fitted trousers and black shoes.
#
# His walking animation is confident and smooth. Arms swing naturally in opposition to his leg movement, with hands likely in lightly clenched fists. He maintains an upright, composed posture with a purposeful stride, looking straight ahead. The animation must loop seamlessly.
#
# The background is a solid, vibrant cyan. The aesthetic should be quintessential 90s 2D fighting game sprite art: featuring clear pixel definition, strong character outlines, and the characteristic animation style of that era. Emphasize the fluidity of the walk cycle and the detailed pixel rendering of both the character and his dynamic attire.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/sold3_39059e8c.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/sold3_39059e8c.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/sold3_39059e8c.mp4
#  18%|█████████████████████████████████████████████████                                                                                                                                                                                                                                     | 6/34 [02:17<10:28, 22.43s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/sold3_39059e8c.mp4:
#  A 16-bit retro gaming style pixel art animation.
# The subject is a female character with vibrant, spiky blue hair. She wears a light beige/khaki tactical vest with dark shoulder accents over a dark undershirt, matching light beige/khaki shorts, black fingerless gloves, and black high-top sneakers with white soles and laces. She has an athletic, toned physique.
#
# The character is performing a confident, rhythmic walk cycle, moving steadily towards the screen right. Her arms swing naturally in opposition to her legs, characteristic of a classic 2D sprite animation. The animation should be a smooth, seamless loop.
#
# The scene is presented in a side-view perspective against a solid, bright cyan background. Emphasize the distinct pixel art aesthetic and fluid character movement.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/robert_b0598187.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/robert_b0598187.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/robert_b0598187.mp4
#  21%|█████████████████████████████████████████████████████████▏                                                                                                                                                                                                                            | 7/34 [02:36<09:39, 21.47s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/robert_b0598187.mp4:
#  Pixel art animation, 2D side view.
# A male character with short, black, slicked-back hair (pompadour style) walks confidently from right to left across the screen. He has a focused expression.
# He wears a black, high-collared long-sleeved shirt under an open, tan-colored, short-sleeved vest.
# His hands are covered by white gloves.
# He sports light grey, slightly loose-fitting trousers, possibly with a subtle vertical texture, and black shoes with white soles.
# The character's movement is a smooth, multi-frame walk cycle, characteristic of a 90s arcade fighting game sprite. His arms swing naturally with his stride.
# The background is a solid, bright cyan.
# The overall style is retro gaming.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/Billy2_fcf6b840.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/Billy2_fcf6b840.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/Billy2_fcf6b840.mp4
#  24%|█████████████████████████████████████████████████████████████████▍                                                                                                                                                                                                                    | 8/34 [02:55<08:55, 20.60s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/Billy2_fcf6b840.mp4:
#  A 2D pixel art animation showcases a muscular male character, in a style typical of a side-scrolling beat 'em up or fighting game. He has a determined facial expression.
# He sports a red bandana tied around his head, with some brown hair visible. His attire consists of blue denim overalls, the straps resting over his bare, well-defined chest. A small red patch or logo is visible on the bib pocket of the overalls. He wears sturdy brown work boots and black fingerless gloves.
# In his right hand, he firmly grips a long, thick red pole or staff, which is carried over his right shoulder.
# The character is depicted in a clear side view, executing a continuous walking animation cycle. He walks with a confident, somewhat exaggerated stride, characteristic of game animations. His left arm swings naturally by his side, fist clenched, while his right arm maintains its grip on the pole, which bobs slightly in rhythm with his steps.
# The entire animation is set against a vibrant, solid cyan blue background. The visual style is retro, pixelated, and clearly evokes classic 90s arcade fighting games.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/andy_c5d587bb.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/andy_c5d587bb.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/andy_c5d587bb.mp4
#  26%|█████████████████████████████████████████████████████████████████████████▌                                                                                                                                                                                                            | 9/34 [03:16<08:39, 20.78s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/andy_c5d587bb.mp4:
#  Retro 16-bit pixel art animation, evoking a classic 90s fighting game aesthetic (SNK or Capcom style).
# The subject is a muscular male character with long, shaggy blonde hair. He's dressed in a sleeveless white martial arts top with distinct red trim and a red sash tied around his waist, complemented by loose white pants tucked into tall, dark red boots. Red wristbands adorn his wrists.
#
# The character is executing a smooth, confident walking animation cycle, moving purposefully from right to left. His posture is upright, maintaining a fighter's readiness, and his arms swing naturally with his gait. The animation should loop seamlessly.
#
# The animation is presented in a 2D side view, set against a solid, vibrant cyan background. Emphasize clean sprite animation, characteristic of the era.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/ryo_edb3c555.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/ryo_edb3c555.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/ryo_edb3c555.mp4
#  29%|█████████████████████████████████████████████████████████████████████████████████▍                                                                                                                                                                                                   | 10/34 [03:39<08:31, 21.33s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/ryo_edb3c555.mp4:
#  A 2D pixel art animation features a muscular male martial artist character, reminiscent of classic fighting game protagonists. He has short, spiky blonde hair. His outfit consists of a tattered, sleeveless orange martial arts gi top and matching orange trousers, both with frayed edges. He wears dark hand wraps and simple dark foot/ankle wraps.
#
# The character executes a deliberate, strong walk cycle in place, viewed from the side, facing towards the right of the screen. His arms are bent, one forward and one back, alternating with each step in a prepared fighting stance, fists loosely clenched, conveying readiness and a slight bounce in his step.
#
# The animation should have a retro, lo-fi, 16-bit era fighting game sprite aesthetic. The background is a solid, bright cyan. The walk cycle should be smooth and loopable.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/lee2_ff5c4c98.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/lee2_ff5c4c98.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/lee2_ff5c4c98.mp4
#  32%|█████████████████████████████████████████████████████████████████████████████████████████▌                                                                                                                                                                                           | 11/34 [04:07<09:03, 23.65s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/lee2_ff5c4c98.mp4:
#  Generate a pixel art, 2D side-view animation of a fighting game character's walk cycle. The character has spiky, upward-swept white hair and wears bright green goggles or a visor. His outfit is a martial arts uniform featuring a black, long-sleeved inner shirt with gold trim at the cuffs and collar, and voluminous white baggy pants paired with simple black shoes. Over the shirt, he wears a white, sleeveless, open-front robe with thick black trim; this robe has long, distinct panels hanging down the front center and back center. He walks with a determined, rhythmic gait, fists lightly clenched, and arms swinging naturally in opposition to his leg movement. The animation should be a smooth, looping walk cycle. The background is a solid, vibrant cyan. The aesthetic should be reminiscent of classic 16-bit or 32-bit arcade fighting game sprites.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/joe_0b4a2f6b.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/joe_0b4a2f6b.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/joe_0b4a2f6b.mp4
#  35%|█████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                                                                                                                                   | 12/34 [04:26<08:02, 21.95s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/joe_0b4a2f6b.mp4:
#  Side-view pixel art animation of a muscular male fighter performing a classic fighting game walk cycle. The character features short, spiky dark brown hair, tan skin, and an athletic, well-defined physique. He is shirtless, dressed in vibrant red Muay Thai shorts accented with a yellow trim. His fists and forearms are wrapped in white athletic tape, and he wears dark ankle wraps. He advances forward maintaining a combat-ready stance: left leg forward, right leg back, with fists held up near his chin. The walking animation is smooth, with a characteristic subtle bobbing motion, evoking a retro 2D fighting game sprite. The background is a uniform, bright cyan. Ensure a looping animation.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/sold2_fcc7f4c8.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/sold2_fcc7f4c8.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/sold2_fcc7f4c8.mp4
#  38%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                                                                                                                                           | 13/34 [04:43<07:12, 20.57s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/sold2_fcc7f4c8.mp4:
#  Generate a pixel art sprite animation of a muscular male character in a side view. He has short, swept-back brown hair and wears dark, wraparound sunglasses. His attire includes a dark blue, sleeveless, padded vest (possibly tactical gear) over a bare or tightly-clad chest, revealing his well-defined arms. He wears loose-fitting, slightly rumpled orange cargo pants tucked into sturdy dark brown work boots. His fists are clenched.
#
# The character is performing a confident walking animation, a classic game walk cycle. His arms swing in natural opposition to his legs, and his body has a slight up-and-down bob with each step, conveying a sense of readiness or a slight swagger.
#
# The visual style is distinctly retro, reminiscent of 16-bit or 32-bit era arcade fighting games or side-scrolling beat 'em ups. The entire animation is set against a solid, vibrant cyan background.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/king_2b57a1ab.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/king_2b57a1ab.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/king_2b57a1ab.mp4
#  41%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                                                                                                                   | 14/34 [05:03<06:51, 20.55s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/king_2b57a1ab.mp4:
#  Pixel art animation of a retro gaming sprite, reminiscent of 16-bit or 32-bit era fighting games.
# The character is a dapper male figure with neatly styled, swept-back blonde hair. He wears a distinctive, dark magenta or deep purple cropped jacket with an open front, possibly made of a shiny material like satin. Underneath, he has a white collared shirt, the collar visible, and wears short white gloves. His trousers are the same dark magenta/purple color as his jacket, and he sports black dress shoes.
#
# The character is performing a confident, slightly flamboyant walking animation in a side-view perspective, moving from right to left. His arms are bent, hands held up near his chest and face in a stylish, almost defensive or ready posture, moving rhythmically with his stride. His legs move in a smooth walk cycle.
# The background is a solid, vibrant cyan color. The animation should be a seamless loop.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/eiji_e4302712.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/eiji_e4302712.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/eiji_e4302712.mp4
#  44%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                                                                                          | 15/34 [05:23<06:23, 20.20s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/eiji_e4302712.mp4:
#  Generate a detailed pixel art sprite animation of a muscular male martial artist character, reminiscent of a 90s 2D fighting game. The character has dark hair tied back (possibly a topknot or short ponytail) and a subtle goatee. He wears a dark navy blue or black sleeveless gi top with distinctive red trim, open at the chest to reveal a red undershirt or chest wrap. His lower attire consists of matching baggy, dark-colored hakama-style pants, tucked into beige or light grey shin guards/leg wraps that feature red accents or straps. He sports red footwear and red wristbands.
#
# The animation should depict a smooth walk cycle where the character moves from right to left across the screen. Crucially, he maintains a guarded fighting stance as he walks: fists clenched near his chest, arms bent in a ready position, and a slightly crouched, alert posture. His movement should be purposeful yet fluid.
#
# The entire animation is presented in a 2D side view against a solid, bright cyan background, emphasizing a clean, retro gaming aesthetic.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/john_0b05db4d.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/john_0b05db4d.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/john_0b05db4d.mp4
#  47%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                                                                                                                  | 16/34 [05:46<06:19, 21.10s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/john_0b05db4d.mp4:
#  A 2D pixel art animation of a male character performing a walk cycle, in side view. He is walking from left to right across the screen. The style is reminiscent of classic 90s arcade fighting game sprites.
#
# The character is muscular, with medium-length, spiky blond hair that might be somewhat slicked back, and he wears dark sunglasses. His attire consists of a white short-sleeved shirt visible under a dark olive green utility vest with pockets. He wears matching dark olive green cargo pants, red fingerless gloves or hand wraps, and sturdy brown combat boots.
#
# He walks with a confident, determined gait. The background is a solid, bright cyan color. The animation showcases a clean, well-defined pixel art aesthetic.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/big_4d196cd5.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/big_4d196cd5.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/big_4d196cd5.mp4
#  50%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                                                                                          | 17/34 [06:05<05:45, 20.35s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/big_4d196cd5.mp4:
#  Pixel art sprite animation of a cool, bald, muscular man with a dark goatee and small, round sunglasses. He performs a confident, slightly swaggering walk cycle in a side-view perspective. His attire consists of a long, dark grey trench coat featuring a thick, light-colored fur collar and lighter trim, worn over an orange collared shirt, light beige pants, and brown dress shoes. In his left hand, he firmly holds a short, black cylindrical object near his waist. His right hand grips a longer, black cylindrical object, resembling a baton or weapon part, held diagonally upwards. The animation is a seamless loop. The background is a striking, solid cyan. The visual style is highly detailed pixel art, characteristic of a 16-bit or 32-bit era fighting game character.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/rat_571fd4ef.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/rat_571fd4ef.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/rat_571fd4ef.mp4
#  53%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                                                                                                  | 18/34 [06:22<05:10, 19.42s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/rat_571fd4ef.mp4:
#  Pixel art animation, 2D side-scrolling view.
# A male character with short, spiky dark blue hair and an athletic, lean muscular build. He's wearing a tight, burnt orange sleeveless tank top, black fingerless gloves that reach his mid-forearms (possibly with subtle dark blue accents), black fitted pants, and black combat boots.
# He performs a confident, rhythmic walk cycle, moving purposefully from right to left across the screen. His arms swing naturally with his stride, fists slightly clenched.
# The background is a solid, vibrant cyan blue.
# The overall aesthetic is that of a 16-bit or early 32-bit era side-scrolling beat 'em up or fighting game character sprite. The animation should loop smoothly.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/jack_5bcb9d6c.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/jack_5bcb9d6c.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/jack_5bcb9d6c.mp4
#  56%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                                                                          | 19/34 [06:44<05:04, 20.28s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/jack_5bcb9d6c.mp4:
#  Retro pixel art animation of a strong, muscular, blonde-haired man with a tough demeanor. He wears a tight blue sleeveless vest, dark grey or black pants, and brown combat-style boots, with a black wristband on his left wrist. The character is shown in a side profile view, executing a walking animation from left to right, typical of a 2D side-scrolling beat 'em up game. His powerful arms are bent and swing in sync with his determined stride, and his body has a slight rhythmic bob as he moves. The pixel art is clear, with distinct outlines and blocky shading, capturing a 16-bit aesthetic. The entire animation is set against a solid, vibrant, bright cyan background.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/jack2_8d046130.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/jack2_8d046130.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/jack2_8d046130.mp4
#  59%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                                                                                  | 20/34 [07:06<04:52, 20.87s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/jack2_8d046130.mp4:
#  Generate a 16-bit pixel art animation of a brawny, tough-looking male character, reminiscent of a classic side-scrolling beat 'em up game. He possesses shaggy, medium-length blonde hair and a powerful, muscular build, complete with a noticeable paunch. His attire consists of a blue, sleeveless denim-style vest, dark grey or black weathered pants, and sturdy brown boots. A dark bracer is visible on his left wrist.
#
# The character is executing a confident walking animation loop, moving from right to left across the screen. His arms are bent at the elbows, fists loosely clenched, swinging rhythmically in opposition to his leg movements, maintaining a ready, brawler-like stance. This action is presented from a clear side-view perspective. The entire animation is set against a solid, bright cyan background.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/terry_59dc4c2a.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/terry_59dc4c2a.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/terry_59dc4c2a.mp4
#  62%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                                                          | 21/34 [07:39<05:15, 24.24s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/terry_59dc4c2a.mp4:
#  Detailed 2D pixel art animation of a male fighting game character executing a walk cycle. He has blonde hair peeking from under a red and white trucker cap facing forward. This muscular character wears a red, open sleeveless vest with a white collar over a white short-sleeved t-shirt, complemented by dark fingerless gloves, dark blue jeans, and red and white sneakers. He walks purposefully from left to right in a side-view perspective, fists clenched and arms bent in a classic fighting stance. The walk animation is smooth and designed to loop seamlessly. The background is a vibrant, solid bright cyan. The aesthetic is quintessential 90s arcade fighting game sprite work.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/micky_93900ccd.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/micky_93900ccd.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/micky_93900ccd.mp4
#  65%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                                 | 22/34 [08:00<04:40, 23.36s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/micky_93900ccd.mp4:
#  A 16-bit pixel art sprite animation of a muscular male fighter. He has long, dark brown hair that reaches his shoulders and a focused expression. He's wearing a white, loose-fitting sleeveless tank top, red athletic shorts detailed with white vertical side stripes and white trim at the leg openings, and red and white high-top sneakers.
#
# The character is performing a walk cycle, moving towards the right side of the screen while maintaining a side-view profile. His fists are raised in a guarded fighting stance near his chin as he walks with a steady, determined gait.
#
# The animation style is reminiscent of classic arcade beat 'em up or fighting games. The entire animation is set against a solid, bright cyan background. The walk cycle should be smooth and loopable.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/Billy_d8b89536.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/Billy_d8b89536.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/Billy_d8b89536.mp4
#  68%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                                                         | 23/34 [08:17<03:55, 21.38s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/Billy_d8b89536.mp4:
#  Pixel art, 2D side-scroller video game character with a distinct fighting game aesthetic. He is a muscular man wearing blue denim overalls, with the right strap hanging down, exposing his bare right chest and shoulder. He has a red bandana tied around his head, dark brown fingerless gloves, and dark brown work boots. He confidently carries a long red bo staff resting on his right shoulder, held by his right hand.
#
# The character performs a fluid walk cycle animation, walking in place as if moving from left to right across the screen, but remaining centered. His left arm swings naturally while his right arm stabilizes the staff. The animation showcases a confident, slightly swaggering gait.
#
# The scene is set against a solid, vibrant cyan background. Side view, medium shot, maintaining a fixed perspective on the character.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/karate_92eee5df.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/karate_92eee5df.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/karate_92eee5df.mp4
#  71%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                                 | 24/34 [08:36<03:27, 20.79s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/karate_92eee5df.mp4:
#  Pixel art, 2D fighting game sprite animation. A powerfully built, older male martial arts master with wild, spiky white hair reaching his shoulders. He wears a distinctive red mask covering his eyes. His attire is a dark grey or deep purple karate gi with sleeves rolled to the elbow, and black wristbands. He is barefoot.
#
# The character is engaged in a determined walking animation, viewed from a side profile, moving towards the right of the screen. His walk cycle is deliberate and slightly exaggerated; as one leg steps forward, the opposite arm swings forward, bent at the elbow with a clenched fist. He maintains a slight forward lean and a steady, rhythmic pace. The background is a flat, vibrant cyan. The animation style is reminiscent of classic 16-bit era arcade fighting games.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/shoto2_e6a643fb.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/shoto2_e6a643fb.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/shoto2_e6a643fb.mp4
#  74%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                                         | 25/34 [08:57<03:06, 20.71s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/shoto2_e6a643fb.mp4:
#  Pixel art sprite animation of a muscular male martial artist. He has short black hair, tanned skin, and wears a white headband. He is bare-chested, revealing well-defined pectoral and abdominal muscles. A black martial arts belt (obi) is tied around his waist, over loose-fitting white karate-style pants with slightly frayed or rolled-up cuffs. On his feet, he wears traditional Japanese geta sandals.
#
# The character is performing a determined walk cycle animation, moving from screen right to left. His arms are bent and held up in front of his chest in a classic fighting game ready stance, hands open and fingers spread, moving slightly in sync with his steps. His knees are bent, and his body sways subtly with each step, conveying a sense of readiness and controlled movement.
#
# The animation is depicted in a side view, 2D perspective, characteristic of a 16-bit era fighting game. The background is a solid, bright cyan color.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/shoto1_ef558569.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/shoto1_ef558569.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/shoto1_ef558569.mp4
#  76%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                 | 26/34 [09:17<02:44, 20.54s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/shoto1_ef558569.mp4:
#  Create a pixel art animation video. The subject is a male martial artist viewed from the side. He has spiky brown hair and a white headband. He's wearing a white karate gi (kimono-style top and pants) fastened with a black belt, and black wristbands. The character is barefoot.
# The animation shows a looping walk cycle as he moves forward. While walking, he maintains a fighting stance, with his hands raised in a defensive or ready position near his upper body.
# The art style should be reminiscent of 90s 2D arcade fighting game sprites. The background is a flat, solid bright cyan. Ensure the walk animation is fluid for a pixel art style.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/lucky_0c899c37.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/lucky_0c899c37.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/lucky_0c899c37.mp4
#  79%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                         | 27/34 [09:35<02:18, 19.77s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/lucky_0c899c37.mp4:
#  Pixel art game character sprite animation. A dark-skinned male with an athletic build confidently walks. He wears a purple bandana, dark sunglasses, and a black and purple tracksuit jacket with prominent yellow/gold trim and zipper, open to reveal a yellow/gold undershirt. His bottoms are matching purple athletic shorts with yellow/gold trim. He sports light-colored sneakers with yellow/gold accents and wristbands.
#
# The animation is a smooth, looping walk cycle, viewed from the side, showcasing a cool, rhythmic swagger. His arms swing naturally, and there's a slight bounce to his gait as he moves. The background is a solid, vibrant cyan. Focus on a clean, retro pixel art style, reminiscent of 90s fighting or beat 'em up games.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/todo_4e5be871.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/todo_4e5be871.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/todo_4e5be871.mp4
#  82%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                 | 28/34 [09:58<02:04, 20.79s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/todo_4e5be871.mp4:
#  A pixel art 2D sprite animation of a muscular male martial artist, reminiscent of classic 16-bit or 32-bit fighting game characters. He has dark, shoulder-length hair tied back, prominent sideburns, and a full beard. His attire consists of a white, short-sleeved gi top with red trim or an undershirt visible at the collar and cuffs, paired with very dark, wide-legged hakama pants secured by a white sash. He appears barefoot.
#
# The character is performing a deliberate walk cycle, moving from left to right from a side-view perspective. His arms are held up in a ready fighting stance, elbows bent, and hands open or loosely fisted, maintaining this guard as he strides forward with a confident gait.
#
# The entire animation is set against a solid, vibrant cyan background, typical of sprite sheets or character selection screens. The movement should be smooth and loopable.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/punk1_280c48a5.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/punk1_280c48a5.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/punk1_280c48a5.mp4
#  85%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                        | 29/34 [10:17<01:40, 20.16s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/punk1_280c48a5.mp4:
#  A 2D pixel art sprite of a male fighting game character, side view. He has short, spiky dark brown hair with a reddish tint. He wears a sleeveless, high-collared deep red vest with black trim over a black undershirt, revealing muscular arms. His trousers are dark grey or black, and he wears dark boots. Red fingerless gloves cover his hands.
#
# The character performs a confident, purposeful walking animation cycle. His arms are bent, fists clenched, swinging rhythmically as he strides forward with a slight bounce. The animation should loop smoothly. The background is a solid, vibrant cyan. Focus on a retro arcade game aesthetic for the sprite and animation.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/brian_5c4f10a2.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/brian_5c4f10a2.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/brian_5c4f10a2.mp4
#  88%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                | 30/34 [10:35<01:18, 19.71s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/brian_5c4f10a2.mp4:
#  A 16-bit pixel art animation of a muscular male character, in a retro arcade fighting game style. He has short, auburn or reddish-brown hair. He wears a dark blue short-sleeved t-shirt, light blue jeans, and white sneakers with blue trim. A distinctive feature is a large, rounded white shoulder pad on his left shoulder, and he also wears white wristbands. The character is performing a confident walking animation loop, viewed from the side, as if striding forward. His arms swing with clenched fists. The background is a solid, vibrant cyan. Side-view, medium shot.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/punk4_2a2be0cc.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/punk4_2a2be0cc.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/punk4_2a2be0cc.mp4
#  91%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                        | 31/34 [10:56<00:59, 19.91s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/punk4_2a2be0cc.mp4:
#  Side view, 2D pixel art animation of a young adult male character with a fighting game aesthetic. He has short, spiky brown hair and a confident demeanor. He wears a dark, open sleeveless jacket or vest over a charcoal grey t-shirt, dark pants, and dark shoes, complemented by dark fingerless gloves. His fists are clenched as he executes a smooth, determined walk cycle, moving forward towards the right of the frame. The background is a solid, vibrant cyan. Focus on the character's rhythmic movement and classic fighting game sprite style.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/sold1_0765e834.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/sold1_0765e834.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/sold1_0765e834.mp4
#  94%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                | 32/34 [11:18<00:41, 20.58s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/sold1_0765e834.mp4:
#  A pixel art animation of a muscular male fighter character, side view, performing a determined walk cycle, moving towards the left of the screen.
# He wears a black baseball cap (forward), a black t-shirt visible under an open, sleeveless khaki utility vest with pockets, and matching khaki cargo pants. He also wears black fingerless gloves and black boots.
# His arms swing naturally and rhythmically with his stride, fists slightly clenched, conveying a sense of purpose.
# The art style is classic 16-bit arcade fighting game sprite, featuring clean pixel lines and a limited color palette.
# The animation is a smooth, looping walk cycle.
# The background is a solid, vibrant cyan.
# Focus: character, walk animation, pixel art, side-scrolling.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/heid_b69aa7ff.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/heid_b69aa7ff.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/heid_b69aa7ff.mp4
#  97%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊        | 33/34 [11:35<00:19, 19.62s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/heid_b69aa7ff.mp4:
#  A pixel art, 2D sprite animation of a muscular male character, reminiscent of a 90s fighting game. He has short, slicked-back white hair and wears dark, goggle-like sunglasses. His attire consists of a sleek white military-style jumpsuit with a prominent red insignia on his right shoulder/upper arm, black gloves, and black knee-high combat boots.
#
# The character is performing a confident, purposeful walk cycle, striding from left to right. His arms swing naturally, with his left arm coming forward as his right leg steps, and vice versa. The animation is smooth and looped, showcasing a classic side-view walk.
#
# The entire animation is set against a solid, vibrant cyan background, ensuring the character sprite stands out clearly.
# processing /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/john2_ad95064a.mp4
# uploading /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/john2_ad95064a.mp4, True, /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/john2_ad95064a.mp4
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 34/34 [12:04<00:00, 21.31s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/john2_ad95064a.mp4:
#  A pixel art, side-view video of a male fighting game character performing a smooth, looped walk cycle. The character has a muscular build, blonde, swept-back hair, and wears sunglasses. His attire consists of a green utility vest open over a white short-sleeved t-shirt, red fingerless gloves, dark olive-green pants, and brown combat boots. He walks with a confident, slightly swaggering gait, his arms swinging naturally. The animation style is reminiscent of classic 2D arcade fighting game sprites from the 90s. The background is a striking, solid bright cyan. Focus on the detailed pixel work, the character's distinctive look, and the fluidity of the walk animation.

# %%
pfn
# Out:
# 'Billy.txt'
# ERROR! Session/line number was not unique in database. History logging moved to new session 1340
