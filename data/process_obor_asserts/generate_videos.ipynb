# %%
# %cd /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/data/chars
# Out:
# /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/data/chars

# %%
# !python ../../../../../diffusion-pipe/data/process_obor_asserts/process_obor_assets.py fterry/terry.txt --offset-x-ratio 0.4222 --offset-y-ratio 0.8739 --canvas-color "#00ffff" --scale-ratio 2.0 --repeat-fill 13
# Out:
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Attempting to generate video using ffmpeg for waiting
# Generated video with ffmpeg: waiting.mp4 (7 frames)
# Attempting to generate video using ffmpeg for select
# Generated video with ffmpeg: select.mp4 (22 frames)
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (10 frames)
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (12 frames)
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (8 frames)
# Attempting to generate video using ffmpeg for run
# Generated video with ffmpeg: run.mp4 (8 frames)
# Attempting to generate video using ffmpeg for runattack
# Generated video with ffmpeg: runattack.mp4 (28 frames)
# Attempting to generate video using ffmpeg for runjumpattack
# Generated video with ffmpeg: runjumpattack.mp4 (9 frames)
# Attempting to generate video using ffmpeg for block
# Generated video with ffmpeg: block.mp4 (9 frames)
# Attempting to generate video using ffmpeg for attackup
# Generated video with ffmpeg: attackup.mp4 (7 frames)
# Attempting to generate video using ffmpeg for attackdown
# Generated video with ffmpeg: attackdown.mp4 (7 frames)
# Attempting to generate video using ffmpeg for attack1
# Generated video with ffmpeg: attack1.mp4 (6 frames)
# Attempting to generate video using ffmpeg for attack2
# Generated video with ffmpeg: attack2.mp4 (7 frames)
# Attempting to generate video using ffmpeg for attack3
# Generated video with ffmpeg: attack3.mp4 (10 frames)
# Attempting to generate video using ffmpeg for attack4
# Generated video with ffmpeg: attack4.mp4 (7 frames)
# Attempting to generate video using ffmpeg for attack5
# Generated video with ffmpeg: attack5.mp4 (10 frames)
# Attempting to generate video using ffmpeg for attack6
# Generated video with ffmpeg: attack6.mp4 (7 frames)
# Attempting to generate video using ffmpeg for attack7
# Generated video with ffmpeg: attack7.mp4 (13 frames)
# Attempting to generate video using ffmpeg for chargeattack
# Generated video with ffmpeg: chargeattack.mp4 (15 frames)
# Attempting to generate video using ffmpeg for jumpdelay
# Generated video with ffmpeg: jumpdelay.mp4 (3 frames)
# Attempting to generate video using ffmpeg for jumpland
# Generated video with ffmpeg: jumpland.mp4 (3 frames)
# Attempting to generate video using ffmpeg for jump
# Generated video with ffmpeg: jump.mp4 (11 frames)
# Attempting to generate video using ffmpeg for runjump
# Generated video with ffmpeg: runjump.mp4 (10 frames)
# Attempting to generate video using ffmpeg for jumpattack
# Generated video with ffmpeg: jumpattack.mp4 (9 frames)
# Attempting to generate video using ffmpeg for jumpattack2
# Generated video with ffmpeg: jumpattack2.mp4 (3 frames)
# Attempting to generate video using ffmpeg for special
# Generated video with ffmpeg: special.mp4 (18 frames)
# Attempting to generate video using ffmpeg for charge
# Generated video with ffmpeg: charge.mp4 (8 frames)
# Attempting to generate video using ffmpeg for cant
# Generated video with ffmpeg: cant.mp4 (11 frames)
# Attempting to generate video using ffmpeg for grab
# Generated video with ffmpeg: grab.mp4 (18 frames)
# Attempting to generate video using ffmpeg for grabattack
# Generated video with ffmpeg: grabattack.mp4 (7 frames)
# Attempting to generate video using ffmpeg for grabforward
# Generated video with ffmpeg: grabforward.mp4 (7 frames)
# Attempting to generate video using ffmpeg for grabattack2
# Generated video with ffmpeg: grabattack2.mp4 (16 frames)
# Attempting to generate video using ffmpeg for grabforward2
# Generated video with ffmpeg: grabforward2.mp4 (22 frames)
# Attempting to generate video using ffmpeg for throw
# Generated video with ffmpeg: throw.mp4 (12 frames)
# Attempting to generate video using ffmpeg for grabbed
# Generated video with ffmpeg: grabbed.mp4 (18 frames)
# Attempting to generate video using ffmpeg for pain
# Generated video with ffmpeg: pain.mp4 (5 frames)
# Attempting to generate video using ffmpeg for pain2
# Generated video with ffmpeg: pain2.mp4 (5 frames)
# Attempting to generate video using ffmpeg for pain3
# Generated video with ffmpeg: pain3.mp4 (19 frames)
# Attempting to generate video using ffmpeg for fall
# Generated video with ffmpeg: fall.mp4 (60 frames)
# Attempting to generate video using ffmpeg for fall2
# Generated video with ffmpeg: fall2.mp4 (60 frames)
# Attempting to generate video using ffmpeg for fall3
# Generated video with ffmpeg: fall3.mp4 (60 frames)
# Warning: Image not found: fterry/burn1.gif
# Warning: Image not found: fterry/burn2.gif
# Attempting to generate video using ffmpeg for burn
# Generated video with ffmpeg: burn.mp4 (4 frames)
# Attempting to generate video using ffmpeg for rise
# Generated video with ffmpeg: rise.mp4 (8 frames)
# Attempting to generate video using ffmpeg for freespecial2
# Generated video with ffmpeg: freespecial2.mp4 (19 frames)
# Attempting to generate video using ffmpeg for freespecial3
# Generated video with ffmpeg: freespecial3.mp4 (27 frames)
# Attempting to generate video using ffmpeg for freespecial4
# Generated video with ffmpeg: freespecial4.mp4 (19 frames)
# Attempting to generate video using ffmpeg for freespecial5
# Generated video with ffmpeg: freespecial5.mp4 (12 frames)
# Attempting to generate video using ffmpeg for freespecial6
# Generated video with ffmpeg: freespecial6.mp4 (15 frames)
# Attempting to generate video using ffmpeg for freespecial7
# Generated video with ffmpeg: freespecial7.mp4 (47 frames)
# Attempting to generate video using ffmpeg for freespecial8
# Generated video with ffmpeg: freespecial8.mp4 (10 frames)
# Attempting to generate video using ffmpeg for freespecial1
# Generated video with ffmpeg: freespecial1.mp4 (12 frames)
# Attempting to generate video using ffmpeg for follow1
# Generated video with ffmpeg: follow1.mp4 (77 frames)
# Generated JSON summary: terry_animations.json
#
# Animation generation completed successfully!
# Summary saved to: terry_animations.json

# %%
# !ls *.mp4
# Out:
# attack1.mp4       chargeattack.mp4  grab.mp4          pain2.mp4
# attack2.mp4       fall.mp4          grabattack.mp4    pain3.mp4
# attack3.mp4       fall2.mp4         grabattack2.mp4   rise.mp4
# attack4.mp4       fall3.mp4         grabbed.mp4       run.mp4
# attack5.mp4       follow1.mp4       grabforward.mp4   runattack.mp4
# attack6.mp4       freespecial1.mp4  grabforward2.mp4  runjump.mp4
# attack7.mp4       freespecial2.mp4  idle.mp4          runjumpattack.mp4
# attackdown.mp4    freespecial3.mp4  jump.mp4          select.mp4
# attackup.mp4      freespecial4.mp4  jumpattack.mp4    spawn.mp4
# block.mp4         freespecial5.mp4  jumpattack2.mp4   special.mp4
# burn.mp4          freespecial6.mp4  jumpdelay.mp4     throw.mp4
# cant.mp4          freespecial7.mp4  jumpland.mp4      waiting.mp4
# charge.mp4        freespecial8.mp4  pain.mp4          walk.mp4

# %%
chars_str = """1ryo/ryo.txt
1ryo/ryobike.txt
1robert/robert.txt
1robert/robcar.txt
1yuri/yuri.txt
fterry/terry.txt
fandy/andy.txt
fjoe/joe.txt
2punk1/punk1.txt
2punk2/punk2.txt
2punk3/punk3.txt
2punk4/punk4.txt
2rat/rat.txt
2lucky/lucky.txt
2brian/brian.txt
2heid/heid.txt
4bike1/bikera.txt
4bike1/bikerb.txt
4bike1/bikerc.txt
4bike2/biker1.txt
4bike2/biker2.txt
4bike3/biker3.txt
2shoto1/shoto1.txt
2shoto2/shoto2.txt
3todo/todo.txt
3jack/jack.txt
3jack/jack2.txt
3king/king.txt
3king/king2.txt
3lee/lee.txt
3lee/lee2.txt
3micky/micky.txt
3john/john.txt
3john/john2.txt
3big/big.txt
3karate/karate.txt
5eiji/eiji.txt
5Billy/Billy.txt
5Billy/Billy2.txt
2sold1/sold1.txt
2sold2/sold2.txt
2sold3/sold3.txt
4bike2/ghost1.txt
4bike2/ghost2.txt
4bike2/ghost3.txt
5geese/geese.txt
5geese/geesed.txt
5geese/gagent.txt"""

chars = chars_str.split("\n")
len(chars), chars[0], chars[-1]
# Out:
# (48, '1ryo/ryo.txt', '5geese/gagent.txt')

# %%
import glob
from tqdm import tqdm



for chdir in tqdm(chars):
    print(f"processing {chdir}")
    # !python ../../../../../diffusion-pipe/data/process_obor_asserts/process_obor_assets.py {chdir} --offset-x-ratio 0.4222 --offset-y-ratio 0.8739 --canvas-color "#00ffff" --scale-ratio 2.0 --repeat-fill 13
# Out:
# Generated video with ffmpeg: walk.mp4 (13 frames)
# Attempting to generate video using ffmpeg for attack1
# Generated video with ffmpeg: attack1.mp4 (26 frames)
# Attempting to generate video using ffmpeg for attack2
# Generated video with ffmpeg: attack2.mp4 (29 frames)
# Attempting to generate video using ffmpeg for attack3
# Generated video with ffmpeg: attack3.mp4 (22 frames)
# Attempting to generate video using ffmpeg for attack4
# Generated video with ffmpeg: attack4.mp4 (18 frames)
# Attempting to generate video using ffmpeg for attack5
# Generated video with ffmpeg: attack5.mp4 (47 frames)
# Attempting to generate video using ffmpeg for follow1
# Generated video with ffmpeg: follow1.mp4 (64 frames)
# Attempting to generate video using ffmpeg for special2
# Generated video with ffmpeg: special2.mp4 (14 frames)
# Attempting to generate video using ffmpeg for upper
# Generated video with ffmpeg: upper.mp4 (22 frames)
# Warning: Image not found: 5eiji/empty.gif
# Attempting to generate video using ffmpeg for riseattack
# Generated video with ffmpeg: riseattack.mp4 (17 frames)
# Filling animation 'grabbed' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for grabbed
# Generated video with ffmpeg: grabbed.mp4 (13 frames)
# Filling animation 'pain' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain
# Generated video with ffmpeg: pain.mp4 (13 frames)
# Filling animation 'pain2' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain2
# Generated video with ffmpeg: pain2.mp4 (13 frames)
# Attempting to generate video using ffmpeg for pain3
# Generated video with ffmpeg: pain3.mp4 (17 frames)
# Attempting to generate video using ffmpeg for pain4
# Generated video with ffmpeg: pain4.mp4 (26 frames)
# Filling animation 'pain5' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain5
# Generated video with ffmpeg: pain5.mp4 (13 frames)
# Filling animation 'pain6' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain6
# Generated video with ffmpeg: pain6.mp4 (13 frames)
# Attempting to generate video using ffmpeg for pain7
# Generated video with ffmpeg: pain7.mp4 (39 frames)
# Attempting to generate video using ffmpeg for pain8
# Generated video with ffmpeg: pain8.mp4 (16 frames)
# Attempting to generate video using ffmpeg for pain9
# Generated video with ffmpeg: pain9.mp4 (28 frames)
# Filling animation 'fall' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall
# Generated video with ffmpeg: fall.mp4 (13 frames)
# Filling animation 'fall2' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall2
# Generated video with ffmpeg: fall2.mp4 (13 frames)
# Attempting to generate video using ffmpeg for fall7
# Generated video with ffmpeg: fall7.mp4 (334 frames)
# Filling animation 'fall9' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall9
# Generated video with ffmpeg: fall9.mp4 (13 frames)
# Warning: Image not found: 5eiji/burn1.gif
# Warning: Image not found: 5eiji/burn2.gif
# Repeating animation 'burn' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for burn
# Generated video with ffmpeg: burn.mp4 (13 frames)
# Filling animation 'rise' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for rise
# Generated video with ffmpeg: rise.mp4 (13 frames)
# Attempting to generate video using ffmpeg for death
# Generated video with ffmpeg: death.mp4 (25 frames)
# Generated JSON summary: eiji_animations.json
#
# Animation generation completed successfully!
# Summary saved to: eiji_animations.json
#  77%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                               | 37/48 [06:29<02:13, 12.16s/it]
# processing 5Billy/Billy.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 13 frames
# Filling animation 'block' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for block
# Generated video with ffmpeg: block.mp4 (13 frames)
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (109 frames)
# Repeating animation 'idle' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (13 frames)
# Repeating animation 'walk' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (13 frames)
# Repeating animation 'attack1' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for attack1
# Generated video with ffmpeg: attack1.mp4 (13 frames)
# Attempting to generate video using ffmpeg for attack2
# Generated video with ffmpeg: attack2.mp4 (18 frames)
# Attempting to generate video using ffmpeg for attack3
# Generated video with ffmpeg: attack3.mp4 (21 frames)
# Attempting to generate video using ffmpeg for attack4
# Generated video with ffmpeg: attack4.mp4 (33 frames)
# Attempting to generate video using ffmpeg for upper
# Generated video with ffmpeg: upper.mp4 (20 frames)
# Attempting to generate video using ffmpeg for riseattack
# Generated video with ffmpeg: riseattack.mp4 (18 frames)
# Filling animation 'grabbed' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for grabbed
# Generated video with ffmpeg: grabbed.mp4 (13 frames)
# Filling animation 'pain' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain
# Generated video with ffmpeg: pain.mp4 (13 frames)
# Filling animation 'pain2' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain2
# Generated video with ffmpeg: pain2.mp4 (13 frames)
# Attempting to generate video using ffmpeg for pain3
# Generated video with ffmpeg: pain3.mp4 (17 frames)
# Attempting to generate video using ffmpeg for pain4
# Generated video with ffmpeg: pain4.mp4 (26 frames)
# Filling animation 'pain5' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain5
# Generated video with ffmpeg: pain5.mp4 (13 frames)
# Filling animation 'pain6' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain6
# Generated video with ffmpeg: pain6.mp4 (13 frames)
# Attempting to generate video using ffmpeg for pain7
# Generated video with ffmpeg: pain7.mp4 (39 frames)
# Attempting to generate video using ffmpeg for pain8
# Generated video with ffmpeg: pain8.mp4 (16 frames)
# Attempting to generate video using ffmpeg for pain9
# Generated video with ffmpeg: pain9.mp4 (28 frames)
# Filling animation 'fall' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall
# Generated video with ffmpeg: fall.mp4 (13 frames)
# Filling animation 'fall2' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall2
# Generated video with ffmpeg: fall2.mp4 (13 frames)
# Attempting to generate video using ffmpeg for fall7
# Generated video with ffmpeg: fall7.mp4 (334 frames)
# Filling animation 'fall9' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall9
# Generated video with ffmpeg: fall9.mp4 (13 frames)
# Warning: Image not found: 5Billy/burn1.gif
# Warning: Image not found: 5Billy/burn2.gif
# Repeating animation 'burn' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for burn
# Generated video with ffmpeg: burn.mp4 (13 frames)
# Filling animation 'rise' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for rise
# Generated video with ffmpeg: rise.mp4 (13 frames)
# Filling animation 'death' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for death
# Generated video with ffmpeg: death.mp4 (13 frames)
# Generated JSON summary: Billy_animations.json
#
# Animation generation completed successfully!
# Summary saved to: Billy_animations.json
#  79%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                         | 38/48 [06:40<01:59, 11.99s/it]
# processing 5Billy/Billy2.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 13 frames
# Filling animation 'block' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for block
# Generated video with ffmpeg: block.mp4 (13 frames)
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (109 frames)
# Repeating animation 'idle' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (13 frames)
# Repeating animation 'walk' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (13 frames)
# Repeating animation 'attack1' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for attack1
# Generated video with ffmpeg: attack1.mp4 (13 frames)
# Attempting to generate video using ffmpeg for attack2
# Generated video with ffmpeg: attack2.mp4 (18 frames)
# Attempting to generate video using ffmpeg for attack3
# Generated video with ffmpeg: attack3.mp4 (21 frames)
# Attempting to generate video using ffmpeg for attack4
# Generated video with ffmpeg: attack4.mp4 (33 frames)
# Attempting to generate video using ffmpeg for upper
# Generated video with ffmpeg: upper.mp4 (20 frames)
# Attempting to generate video using ffmpeg for riseattack
# Generated video with ffmpeg: riseattack.mp4 (18 frames)
# Filling animation 'grabbed' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for grabbed
# Generated video with ffmpeg: grabbed.mp4 (13 frames)
# Filling animation 'pain' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain
# Generated video with ffmpeg: pain.mp4 (13 frames)
# Filling animation 'pain2' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain2
# Generated video with ffmpeg: pain2.mp4 (13 frames)
# Attempting to generate video using ffmpeg for pain3
# Generated video with ffmpeg: pain3.mp4 (17 frames)
# Attempting to generate video using ffmpeg for pain4
# Generated video with ffmpeg: pain4.mp4 (26 frames)
# Filling animation 'pain5' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain5
# Generated video with ffmpeg: pain5.mp4 (13 frames)
# Filling animation 'pain6' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain6
# Generated video with ffmpeg: pain6.mp4 (13 frames)
# Attempting to generate video using ffmpeg for pain7
# Generated video with ffmpeg: pain7.mp4 (39 frames)
# Attempting to generate video using ffmpeg for pain8
# Generated video with ffmpeg: pain8.mp4 (16 frames)
# Attempting to generate video using ffmpeg for pain9
# Generated video with ffmpeg: pain9.mp4 (28 frames)
# Filling animation 'fall' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall
# Generated video with ffmpeg: fall.mp4 (13 frames)
# Filling animation 'fall2' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall2
# Generated video with ffmpeg: fall2.mp4 (13 frames)
# Attempting to generate video using ffmpeg for fall7
# Generated video with ffmpeg: fall7.mp4 (334 frames)
# Filling animation 'fall9' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall9
# Generated video with ffmpeg: fall9.mp4 (13 frames)
# Warning: Image not found: 5Billy/burn1.gif
# Warning: Image not found: 5Billy/burn2.gif
# Repeating animation 'burn' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for burn
# Generated video with ffmpeg: burn.mp4 (13 frames)
# Filling animation 'rise' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for rise
# Generated video with ffmpeg: rise.mp4 (13 frames)
# Filling animation 'death' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for death
# Generated video with ffmpeg: death.mp4 (13 frames)
# Generated JSON summary: Billy2_animations.json
#
# Animation generation completed successfully!
# Summary saved to: Billy2_animations.json
#  81%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                    | 39/48 [06:52<01:47, 11.91s/it]
# processing 2sold1/sold1.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 13 frames
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (28 frames)
# Repeating animation 'idle' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (13 frames)
# Repeating animation 'walk' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (13 frames)
# Filling animation 'attack1' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for attack1
# Generated video with ffmpeg: attack1.mp4 (13 frames)
# Attempting to generate video using ffmpeg for attack2
# Generated video with ffmpeg: attack2.mp4 (26 frames)
# Attempting to generate video using ffmpeg for follow1
# Generated video with ffmpeg: follow1.mp4 (27 frames)
# Filling animation 'riseattack' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for riseattack
# Generated video with ffmpeg: riseattack.mp4 (13 frames)
# Filling animation 'grabbed' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for grabbed
# Generated video with ffmpeg: grabbed.mp4 (13 frames)
# Filling animation 'pain' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain
# Generated video with ffmpeg: pain.mp4 (13 frames)
# Filling animation 'pain2' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain2
# Generated video with ffmpeg: pain2.mp4 (13 frames)
# Attempting to generate video using ffmpeg for pain3
# Generated video with ffmpeg: pain3.mp4 (17 frames)
# Attempting to generate video using ffmpeg for pain4
# Generated video with ffmpeg: pain4.mp4 (26 frames)
# Filling animation 'pain5' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain5
# Generated video with ffmpeg: pain5.mp4 (13 frames)
# Filling animation 'pain6' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain6
# Generated video with ffmpeg: pain6.mp4 (13 frames)
# Attempting to generate video using ffmpeg for pain7
# Generated video with ffmpeg: pain7.mp4 (39 frames)
# Attempting to generate video using ffmpeg for pain8
# Generated video with ffmpeg: pain8.mp4 (16 frames)
# Attempting to generate video using ffmpeg for pain9
# Generated video with ffmpeg: pain9.mp4 (28 frames)
# Filling animation 'fall' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall
# Generated video with ffmpeg: fall.mp4 (13 frames)
# Filling animation 'fall2' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall2
# Generated video with ffmpeg: fall2.mp4 (13 frames)
# Attempting to generate video using ffmpeg for fall7
# Generated video with ffmpeg: fall7.mp4 (334 frames)
# Filling animation 'fall9' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall9
# Generated video with ffmpeg: fall9.mp4 (13 frames)
# Warning: Image not found: 2sold1/burn1.gif
# Warning: Image not found: 2sold1/burn2.gif
# Repeating animation 'burn' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for burn
# Generated video with ffmpeg: burn.mp4 (13 frames)
# Attempting to generate video using ffmpeg for rise
# Generated video with ffmpeg: rise.mp4 (18 frames)
# Filling animation 'death' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for death
# Generated video with ffmpeg: death.mp4 (13 frames)
# Generated JSON summary: sold1_animations.json
#
# Animation generation completed successfully!
# Summary saved to: sold1_animations.json
#  83%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                              | 40/48 [07:01<01:29, 11.13s/it]
# processing 2sold2/sold2.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 13 frames
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (42 frames)
# Repeating animation 'idle' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (13 frames)
# Repeating animation 'walk' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (13 frames)
# Filling animation 'attack1' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for attack1
# Generated video with ffmpeg: attack1.mp4 (13 frames)
# Attempting to generate video using ffmpeg for attack2
# Generated video with ffmpeg: attack2.mp4 (13 frames)
# Attempting to generate video using ffmpeg for follow1
# Generated video with ffmpeg: follow1.mp4 (32 frames)
# Attempting to generate video using ffmpeg for riseattack
# Generated video with ffmpeg: riseattack.mp4 (13 frames)
# Filling animation 'grabbed' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for grabbed
# Generated video with ffmpeg: grabbed.mp4 (13 frames)
# Filling animation 'pain' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain
# Generated video with ffmpeg: pain.mp4 (13 frames)
# Filling animation 'pain2' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain2
# Generated video with ffmpeg: pain2.mp4 (13 frames)
# Attempting to generate video using ffmpeg for pain3
# Generated video with ffmpeg: pain3.mp4 (17 frames)
# Attempting to generate video using ffmpeg for pain4
# Generated video with ffmpeg: pain4.mp4 (26 frames)
# Filling animation 'pain5' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain5
# Generated video with ffmpeg: pain5.mp4 (13 frames)
# Filling animation 'pain6' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain6
# Generated video with ffmpeg: pain6.mp4 (13 frames)
# Attempting to generate video using ffmpeg for pain7
# Generated video with ffmpeg: pain7.mp4 (39 frames)
# Attempting to generate video using ffmpeg for pain8
# Generated video with ffmpeg: pain8.mp4 (16 frames)
# Attempting to generate video using ffmpeg for pain9
# Generated video with ffmpeg: pain9.mp4 (28 frames)
# Filling animation 'fall' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall
# Generated video with ffmpeg: fall.mp4 (13 frames)
# Filling animation 'fall2' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall2
# Generated video with ffmpeg: fall2.mp4 (13 frames)
# Attempting to generate video using ffmpeg for fall7
# Generated video with ffmpeg: fall7.mp4 (334 frames)
# Filling animation 'fall9' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall9
# Generated video with ffmpeg: fall9.mp4 (13 frames)
# Warning: Image not found: 2sold2/burn1.gif
# Warning: Image not found: 2sold2/burn2.gif
# Repeating animation 'burn' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for burn
# Generated video with ffmpeg: burn.mp4 (13 frames)
# Filling animation 'rise' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for rise
# Generated video with ffmpeg: rise.mp4 (13 frames)
# Filling animation 'death' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for death
# Generated video with ffmpeg: death.mp4 (13 frames)
# Generated JSON summary: sold2_animations.json
#
# Animation generation completed successfully!
# Summary saved to: sold2_animations.json
#  85%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                        | 41/48 [07:10<01:11, 10.28s/it]
# processing 2sold3/sold3.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 13 frames
# Filling animation 'spawn' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (13 frames)
# Repeating animation 'idle' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (13 frames)
# Repeating animation 'walk' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (13 frames)
# Filling animation 'attack1' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for attack1
# Generated video with ffmpeg: attack1.mp4 (13 frames)
# Attempting to generate video using ffmpeg for attack2
# Generated video with ffmpeg: attack2.mp4 (27 frames)
# Attempting to generate video using ffmpeg for attack3
# Generated video with ffmpeg: attack3.mp4 (15 frames)
# Attempting to generate video using ffmpeg for riseattack
# Generated video with ffmpeg: riseattack.mp4 (27 frames)
# Filling animation 'grabbed' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for grabbed
# Generated video with ffmpeg: grabbed.mp4 (13 frames)
# Filling animation 'pain' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain
# Generated video with ffmpeg: pain.mp4 (13 frames)
# Filling animation 'pain2' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain2
# Generated video with ffmpeg: pain2.mp4 (13 frames)
# Attempting to generate video using ffmpeg for pain3
# Generated video with ffmpeg: pain3.mp4 (17 frames)
# Attempting to generate video using ffmpeg for pain4
# Generated video with ffmpeg: pain4.mp4 (26 frames)
# Filling animation 'pain5' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain5
# Generated video with ffmpeg: pain5.mp4 (13 frames)
# Filling animation 'pain6' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain6
# Generated video with ffmpeg: pain6.mp4 (13 frames)
# Attempting to generate video using ffmpeg for pain7
# Generated video with ffmpeg: pain7.mp4 (39 frames)
# Attempting to generate video using ffmpeg for pain8
# Generated video with ffmpeg: pain8.mp4 (16 frames)
# Attempting to generate video using ffmpeg for pain9
# Generated video with ffmpeg: pain9.mp4 (28 frames)
# Filling animation 'fall' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall
# Generated video with ffmpeg: fall.mp4 (13 frames)
# Filling animation 'fall2' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall2
# Generated video with ffmpeg: fall2.mp4 (13 frames)
# Attempting to generate video using ffmpeg for fall7
# Generated video with ffmpeg: fall7.mp4 (334 frames)
# Filling animation 'fall9' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall9
# Generated video with ffmpeg: fall9.mp4 (13 frames)
# Warning: Image not found: 2sold3/burn1.gif
# Warning: Image not found: 2sold3/burn2.gif
# Repeating animation 'burn' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for burn
# Generated video with ffmpeg: burn.mp4 (13 frames)
# Attempting to generate video using ffmpeg for rise
# Generated video with ffmpeg: rise.mp4 (20 frames)
# Filling animation 'death' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for death
# Generated video with ffmpeg: death.mp4 (13 frames)
# Generated JSON summary: sold3_animations.json
#
# Animation generation completed successfully!
# Summary saved to: sold3_animations.json
#  88%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                  | 42/48 [07:18<00:58,  9.70s/it]
# processing 4bike2/ghost1.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 13 frames
# Warning: Image not found: 4bike2/empty.gif
# Warning: Image not found: 4bike2/empty.gif
# Filling animation 'spawn' with idle frames to reach 13 frames (loop=0)
# Warning: Image not found: 4bike2/empty.gif
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (13 frames)
# Warning: Image not found: 4bike2/empty.gif
# Warning: Image not found: 4bike2/empty.gif
# Filling animation 'idle' with idle frames to reach 13 frames (loop=0)
# Warning: Image not found: 4bike2/empty.gif
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (13 frames)
# Warning: Image not found: 4bike2/empty.gif
# Warning: Image not found: 4bike2/empty.gif
# Filling animation 'walk' with idle frames to reach 13 frames (loop=0)
# Warning: Image not found: 4bike2/empty.gif
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (13 frames)
# Generated JSON summary: ghost1_animations.json
#
# Animation generation completed successfully!
# Summary saved to: ghost1_animations.json
#  90%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                            | 43/48 [07:19<00:35,  7.09s/it]
# processing 4bike2/ghost2.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 13 frames
# Warning: Image not found: 4bike2/empty.gif
# Warning: Image not found: 4bike2/empty.gif
# Filling animation 'spawn' with idle frames to reach 13 frames (loop=0)
# Warning: Image not found: 4bike2/empty.gif
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (13 frames)
# Warning: Image not found: 4bike2/empty.gif
# Warning: Image not found: 4bike2/empty.gif
# Filling animation 'idle' with idle frames to reach 13 frames (loop=0)
# Warning: Image not found: 4bike2/empty.gif
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (13 frames)
# Warning: Image not found: 4bike2/empty.gif
# Warning: Image not found: 4bike2/empty.gif
# Filling animation 'walk' with idle frames to reach 13 frames (loop=0)
# Warning: Image not found: 4bike2/empty.gif
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (13 frames)
# Generated JSON summary: ghost2_animations.json
#
# Animation generation completed successfully!
# Summary saved to: ghost2_animations.json
#  92%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                       | 44/48 [07:20<00:21,  5.26s/it]
# processing 4bike2/ghost3.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 13 frames
# Warning: Image not found: 4bike2/empty.gif
# Warning: Image not found: 4bike2/empty.gif
# Filling animation 'spawn' with idle frames to reach 13 frames (loop=0)
# Warning: Image not found: 4bike2/empty.gif
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (13 frames)
# Warning: Image not found: 4bike2/empty.gif
# Warning: Image not found: 4bike2/empty.gif
# Filling animation 'idle' with idle frames to reach 13 frames (loop=0)
# Warning: Image not found: 4bike2/empty.gif
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (13 frames)
# Warning: Image not found: 4bike2/empty.gif
# Warning: Image not found: 4bike2/empty.gif
# Filling animation 'walk' with idle frames to reach 13 frames (loop=0)
# Warning: Image not found: 4bike2/empty.gif
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (13 frames)
# Generated JSON summary: ghost3_animations.json
#
# Animation generation completed successfully!
# Summary saved to: ghost3_animations.json
#  94%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                 | 45/48 [07:21<00:11,  3.98s/it]
# processing 5geese/geese.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 13 frames
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (113 frames)
# Attempting to generate video using ffmpeg for block
# Generated video with ffmpeg: block.mp4 (42 frames)
# Repeating animation 'idle' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (13 frames)
# Repeating animation 'walk' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (13 frames)
# Repeating animation 'run' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for run
# Generated video with ffmpeg: run.mp4 (13 frames)
# Repeating animation 'attack1' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for attack1
# Generated video with ffmpeg: attack1.mp4 (13 frames)
# Attempting to generate video using ffmpeg for follow1
# Generated video with ffmpeg: follow1.mp4 (15 frames)
# Attempting to generate video using ffmpeg for attack2
# Generated video with ffmpeg: attack2.mp4 (33 frames)
# Attempting to generate video using ffmpeg for attack3
# Generated video with ffmpeg: attack3.mp4 (24 frames)
# Attempting to generate video using ffmpeg for attack4
# Generated video with ffmpeg: attack4.mp4 (14 frames)
# Attempting to generate video using ffmpeg for attack5
# Generated video with ffmpeg: attack5.mp4 (14 frames)
# Attempting to generate video using ffmpeg for attack6
# Generated video with ffmpeg: attack6.mp4 (21 frames)
# Attempting to generate video using ffmpeg for riseattack
# Generated video with ffmpeg: riseattack.mp4 (24 frames)
# Attempting to generate video using ffmpeg for upper
# Generated video with ffmpeg: upper.mp4 (18 frames)
# Filling animation 'grabbed' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for grabbed
# Generated video with ffmpeg: grabbed.mp4 (13 frames)
# Filling animation 'pain' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain
# Generated video with ffmpeg: pain.mp4 (13 frames)
# Filling animation 'pain2' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain2
# Generated video with ffmpeg: pain2.mp4 (13 frames)
# Attempting to generate video using ffmpeg for pain3
# Generated video with ffmpeg: pain3.mp4 (17 frames)
# Attempting to generate video using ffmpeg for pain4
# Generated video with ffmpeg: pain4.mp4 (26 frames)
# Filling animation 'pain5' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain5
# Generated video with ffmpeg: pain5.mp4 (13 frames)
# Filling animation 'pain6' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for pain6
# Generated video with ffmpeg: pain6.mp4 (13 frames)
# Attempting to generate video using ffmpeg for pain7
# Generated video with ffmpeg: pain7.mp4 (39 frames)
# Attempting to generate video using ffmpeg for pain8
# Generated video with ffmpeg: pain8.mp4 (16 frames)
# Attempting to generate video using ffmpeg for pain9
# Generated video with ffmpeg: pain9.mp4 (28 frames)
# Filling animation 'fall' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall
# Generated video with ffmpeg: fall.mp4 (13 frames)
# Filling animation 'fall2' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall2
# Generated video with ffmpeg: fall2.mp4 (13 frames)
# Attempting to generate video using ffmpeg for fall7
# Generated video with ffmpeg: fall7.mp4 (334 frames)
# Filling animation 'fall9' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for fall9
# Generated video with ffmpeg: fall9.mp4 (13 frames)
# Warning: Image not found: 5geese/burn1.gif
# Warning: Image not found: 5geese/burn2.gif
# Repeating animation 'burn' to reach 13 frames (loop=1)
# Attempting to generate video using ffmpeg for burn
# Generated video with ffmpeg: burn.mp4 (13 frames)
# Filling animation 'rise' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for rise
# Generated video with ffmpeg: rise.mp4 (13 frames)
# Warning: Image not found: 5geese/empty.gif
# Attempting to generate video using ffmpeg for death
# Generated video with ffmpeg: death.mp4 (81 frames)
# Generated JSON summary: geese_animations.json
#
# Animation generation completed successfully!
# Summary saved to: geese_animations.json
#  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍           | 46/48 [07:33<00:12,  6.33s/it]
# processing 5geese/geesed.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 13 frames
# Attempting to generate video using ffmpeg for spawn
# Generated video with ffmpeg: spawn.mp4 (152 frames)
# Warning: Image not found: 5geese/empty.gif
# Filling animation 'walk' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for walk
# Generated video with ffmpeg: walk.mp4 (13 frames)
# Warning: Image not found: 5geese/empty.gif
# Filling animation 'attack' with idle frames to reach 13 frames (loop=0)
# Attempting to generate video using ffmpeg for attack
# Generated video with ffmpeg: attack.mp4 (13 frames)
# Generated JSON summary: geesed_animations.json
#
# Animation generation completed successfully!
# Summary saved to: geesed_animations.json
#  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏     | 47/48 [07:34<00:04,  4.88s/it]
# processing 5geese/gagent.txt
# Using target offset ratio: (0.4222, 0.8739)
# Using canvas color: #00ffff
# Using scale ratio: 2.0
# Using repeat fill: 13 frames
# Attempting to generate video using ffmpeg for idle
# Generated video with ffmpeg: idle.mp4 (39 frames)
# Generated JSON summary: gagent_animations.json
#
# Animation generation completed successfully!
# Summary saved to: gagent_animations.json
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [07:35<00:00,  9.49s/it]

# %% [markdown]
# # gather animation videos by type

# %%
target_path = '/Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos'

# %%
import glob
from tqdm import tqdm
import os, json

all_animations = set()

for chdir in tqdm(chars):
    json_file = chdir.replace(".txt", "_animations.json")
    if not os.path.exists(json_file):
        print("not found")
    with open(json_file, 'r') as jf:
        videos = json.load(jf)
    for l in videos:
        all_animations.add(l['animation'])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 2913.01it/s]

# %%
for ani in all_animations:
    # !mkdir {target_path}/{ani}

# %%
import shutil
from pathlib import Path
animation_to_info = {}

for chdir in tqdm(chars):
    json_file = chdir.replace(".txt", "_animations.json")
    if not os.path.exists(json_file):
        print("not found")
    with open(json_file, 'r') as jf:
        videos = json.load(jf)
    for l in videos:
        #all_animations.add(l['animation'])
        source_file = f"{os.path.dirname(chdir)}/{l['video']}"
        p = Path(chdir)
        char_name = p.name.split(".")[0]
        shutil.copy(source_file, f"{target_path}/{l['animation']}/{char_name}.mp4")
        
        if l['animation'] not in animation_to_info:
            animation_to_info[l['animation']] = []
        ll = l.copy()
        ll['video'] = f"{char_name}.mp4"
        animation_to_info[l['animation']].append(ll)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 81.56it/s]

# %%
animation_to_info

with open(f"{target_path}/info.json", 'w') as f:
    json.dump(animation_to_info, f)

# %%
import os
os.environ["GEMINI_API_KEY"] = "AIzaSyAxyUUUs5zFnqj33E0kQ_eijZkcgv7BBXo"

os.environ["GEMINI_API_KEY"]
# Out:
# 'AIzaSyAxyUUUs5zFnqj33E0kQ_eijZkcgv7BBXo'

# %%
from google import genai
from google.genai import types


client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])



#video_file_name = "/Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/terry.mp4"
#video_bytes = open(video_file_name, 'rb').read()


myfile = client.files.upload(file=video_file_name)


prompt = "Given this gaming animation of a character walking in side view with solid color background, describe the video. describe the character in detail and the action the character is doing. Don't go beyond 230 words."

# %%
response = client.models.generate_content(
    model="gemini-2.5-pro-preview-05-06", 
    contents=[myfile, prompt]
    #contents=types.Content(
    #    parts=[
    #        genai.types.Part(
    #            inline_data=types.Blob(data=video_bytes, 
    #                                   mime_type='video/mp4',
    #                                   #video_metadata=genai.types.VideoMetadata(start_offset='0s', fps=16)
    #                                  )
    #        ),
    #        genai.types.Part(text=prompt)
    #    ]
    #)
)

print(response.text)
# Out:
# This video showcases a 2D pixel art animation of a character, likely from a classic fighting game, walking from left to right. The background is a solid, bright cyan, which ensures the character stands out.
#
# The character depicted is a muscular male with a confident posture. He sports a red baseball cap with a white front panel, worn backwards, revealing some of his blonde hair. He's dressed in a sleeveless, open red vest over a white undershirt, dark blue denim jeans, and red and white sneakers. His hands are covered in red fingerless gloves, and he maintains clenched fists as he walks.
#
# His action consists of a continuous walk cycle. The animation is smooth, with a characteristic bouncy rhythm often seen in 2D sprite-based fighting games. His arms swing naturally in opposition to his leg movements, conveying a sense of purpose and readiness as he traverses the screen.

# %%
import time
time.sleep(2)

# %%
def get_video_prompt(video_path, animation):
    myfile = client.files.upload(file=video_file_name)
    time.sleep(2)


    prompt = f"Given this gaming {animation} animation of a character in side view with solid color background, we want to generate a video generation prompt that can be used to generate this video. In the prompt, describe the character in detail and the action the character is doing. Don't go beyond 230 words. Only output the prompt, nothing else."

    RETRY = 5
    for i in range(RETRY):
        try:
            response = client.models.generate_content(
                model="gemini-2.5-pro-preview-05-06", 
                contents=[myfile, prompt]
            )
            break
        except Excption as e:
            print(f"error: {e}")
            time.sleep(2)
    return response.text

# %%
get_video_prompt(video_file_name, 'walk')
# Out:
# "Side-view 2D pixel art animation, retro gaming style. A muscular male character, resembling a classic fighting game sprite, walks confidently to the right. He has short blonde hair mostly covered by a red and white baseball cap worn backward. He wears an open red sleeveless vest over a white t-shirt, showing his chest, paired with dark blue denim jeans, red and white sneakers, and dark fingerless gloves. His fists are clenched as he walks with a smooth, rhythmic gait that includes a slight bounce and natural arm swing. The background is a solid, vibrant cyan. The animation should capture the feel of a 16-bit era fighting game character's walk cycle."

# %% [markdown]
# # gen prompt for walking

# %%
for f in tqdm(glob.glob(f"{target_path}/walk/*.mp4")):
    prompt = get_video_prompt(f, 'walk')
    print(f"gend prompt for {f}:\n {prompt}")
    #p = Path(f)
    pfn = f.replace(".mp4", ".txt")
    
    with open(pfn, 'w') as pf:
        pf.write(f"game animation walk {prompt}")
# Out:
#   3%|████████▋                                                                                                                                                                                                                                                                             | 1/32 [00:23<12:08, 23.49s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/lucky.mp4:
#  Side-view, 2D pixel art animation.
# The subject is a muscular male character with short blonde hair, presented in a classic fighting game art style. He wears a red baseball cap backward with a white front panel and brim, an open red sleeveless vest over a white short-sleeved t-shirt, dark blue denim jeans, and red and white sneakers. He also wears fingerless gloves.
#
# The animation begins with the character in a subtle, ready stance, fists clenched and slightly bouncing. He then transitions into a confident, smooth walk cycle, striding forward. His arms swing naturally in rhythm with his steps, conveying a sense of purpose.
#
# The background is a solid, vibrant cyan. The overall visual style should evoke a 90s arcade fighting game sprite, with distinct pixel definition and fluid movement typical of the era.
#   6%|█████████████████▍                                                                                                                                                                                                                                                                    | 2/32 [00:41<10:00, 20.01s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/karate.mp4:
#  Pixel art animation of a muscular male fighting game character, closely resembling Terry Bogard.
# He has blonde hair partially covered by a red and white baseball cap worn backward. He's wearing a red sleeveless vest over a white short-sleeved shirt with rolled-up sleeves, dark blue jeans, and red and white sneakers. He also wears dark fingerless gloves.
# The character is performing a walk cycle animation, moving steadily forward as if in a 2D side-scrolling fighting game. His fists are clenched, and he maintains a slight combat-ready crouch as he walks.
# The perspective is a clear side view. The background is a solid, bright, vibrant cyan. The overall aesthetic is retro 90s arcade game sprite animation.
#   9%|██████████████████████████                                                                                                                                                                                                                                                            | 3/32 [01:02<09:57, 20.60s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/joe.mp4:
#  Generate a 2D pixel art animation of a male fighting game character in a side view. The character is muscular, with blonde hair partially visible under a red baseball cap with a white front panel, worn backwards. He's dressed in a red, open sleeveless vest, a white short-sleeved t-shirt, dark blue denim jeans, and red sneakers with white accents and soles. He also wears dark, fingerless gloves.
#
# The character is performing a confident walking animation, moving forward. His fists are clenched and held up near his chest in a fighting stance, and he has a slight bounce in his step, characteristic of a classic fighting game walk cycle. The animation should be a smooth, looping sequence.
#
# The art style should emulate classic 2D fighting games from the 1990s, featuring clean, well-defined pixel art for the character sprite. The background is a solid, bright cyan color. The overall feel should be energetic and ready for action.
#  12%|██████████████████████████████████▊                                                                                                                                                                                                                                                   | 4/32 [01:27<10:26, 22.39s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/Billy.mp4:
#  Detailed pixel art animation of a 2D fighting game character's walk cycle. The character is a muscular male, depicted in a side view, facing left. He has short blonde hair partially visible under a red baseball cap worn backwards. His attire consists of a red, open sleeveless vest over a white short-sleeved t-shirt, dark fingerless gloves, blue denim jeans, and red and white sneakers.
# The character performs a confident, slightly bouncy in-place walking animation. His fists are clenched, and his arms swing rhythmically in opposition to his leg movements. The animation style should be reminiscent of classic 90s arcade fighting game sprites, with clear pixel definition. The background is a solid, vibrant cyan color. Ensure the animation is a smooth, seamless loop.
#  16%|███████████████████████████████████████████▍                                                                                                                                                                                                                                          | 5/32 [01:47<09:40, 21.49s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/punk4.mp4:
#  Side view, 2D pixel art animation featuring the iconic fighting game character Terry Bogard performing a walk cycle. Terry is depicted as a muscular man with blonde hair visible beneath his signature red baseball cap, which has a white front panel and brim. His attire includes a red, open, sleeveless denim vest with a white collar, exposing his bare chest. He wears dark blue jeans, red fingerless gloves, and red and white sneakers.
#
# Terry walks confidently from left to right across the screen. The animation is a smooth, looping walk cycle, with his arms swinging naturally in rhythm with his gait, and a characteristic slight bounce in his step. The style is that of a detailed, classic 90s arcade fighting game sprite, with clean pixel art. The background is a solid, vibrant cyan color.
#  19%|████████████████████████████████████████████████████▏                                                                                                                                                                                                                                 | 6/32 [02:05<08:49, 20.38s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/lee.mp4:
#  A 2D pixel art animation depicting a muscular male character with short blonde hair, reminiscent of a classic 90s fighting game. He wears a red and white baseball cap (bill forward), a red sleeveless open vest revealing a white undershirt, dark blue jeans, red and white sneakers, and red fingerless gloves.
#
# The character is performing a smooth walk cycle animation, striding purposefully from right to left across the frame. His fists are clenched, and his arms swing naturally in time with his steps, maintaining a confident, ready posture.
#
# The animation is a side view. The background is a solid, vibrant cyan. Looping animation.
#  22%|████████████████████████████████████████████████████████████▊                                                                                                                                                                                                                         | 7/32 [02:41<10:32, 25.31s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/jack.mp4:
#  Pixel art, 2D animation of a muscular male fighter seen from a side view. He has short blonde hair and wears a red baseball cap backwards (white brim visible), an unbuttoned red vest over a white short-sleeved t-shirt, dark blue jeans, red and white sneakers, and brown fingerless gloves. The character performs a confident, looping walk cycle, with a slight bounce in his step, fists clenched in a combat-ready posture. The background is a solid, vibrant cyan. The aesthetic is that of a classic 1990s arcade fighting game character sprite.
#  25%|█████████████████████████████████████████████████████████████████████▌                                                                                                                                                                                                                | 8/32 [02:58<09:03, 22.65s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/micky.mp4:
#  Pixel art animation of a muscular male fighting game character with short blonde hair, mostly obscured by a red baseball cap with a white brim, worn backward. He sports a bright red, open, sleeveless vest over white short-sleeves, revealing his chest. He wears dark blue denim jeans, red and white sneakers, and dark fingerless gloves.
#
# The character executes a smooth, looping walk cycle, moving from left to right across the screen. He maintains a dynamic fighting stance throughout the walk, with fists clenched and raised, and knees slightly bent. The animation is presented in a side-view perspective against a solid, vibrant cyan background, characteristic of retro 2D fighting games.
#  28%|██████████████████████████████████████████████████████████████████████████████▏                                                                                                                                                                                                       | 9/32 [03:21<08:43, 22.75s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/Billy2.mp4:
#  A 2D pixel art video showcasing a fighting game character's walk cycle animation. The character is a muscular male with short blonde hair, wearing a distinctive red cap with a white brim, a red sleeveless vest with a white collar over a white t-shirt, dark blue jeans, and red and white sneakers. His fists are tightly clenched. He performs a slow, deliberate, and rhythmic walk cycle, viewed from the side, typical of classic 90s arcade fighting games. His upper body exhibits a slight confident sway, and his arms swing naturally in opposition to his leg movement, fists remaining closed. The animation is a seamless loop. The background is a solid, vibrant bright cyan. The character maintains a focused, determined expression, ready for action.
#  31%|██████████████████████████████████████████████████████████████████████████████████████▌                                                                                                                                                                                              | 10/32 [03:44<08:25, 22.97s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/punk3.mp4:
#  A 2D pixel art animation showcasing a male fighting game character performing a walk cycle. The character is muscular, with fair skin and long blonde hair tied in a ponytail, extending from beneath a red baseball cap worn backwards. His attire consists of a white short-sleeved shirt with rolled-up sleeves, an open, sleeveless red vest, dark-colored fingerless gloves, classic blue jeans, and red and white sneakers.
#
# The scene is a side-view perspective. He walks forward with a confident, slightly bouncy gait typical of retro fighting games. His arms are bent, fists clenched in a ready/guard position, and they sway naturally with his walking motion. The animation should emulate a classic 2D sprite, with distinct frames and fluid movement. The background is a solid, vibrant cyan. Emphasize the retro gaming aesthetic and the character's iconic fighting stance during the walk.
#  34%|███████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                                                                                                                     | 11/32 [04:12<08:37, 24.67s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/punk2.mp4:
#  Side-view 2D pixel art animation of a muscular male fighting game character. He has short blonde hair, partially covered by a red and white baseball cap worn forwards. He wears a red, open sleeveless vest, revealing a white undershirt or tank top underneath. His arms are bare and muscular, ending in dark fingerless gloves. He wears dark blue denim jeans and red sneakers with white soles and accents.
#
# The character is performing a confident, purposeful walk cycle, moving from the right side of the screen towards the left. His fists are clenched, and his arms swing slightly with each step, maintaining a ready, combative posture. The animation is a smooth loop showing several steps. The background is a solid, vibrant cyan. The art style is reminiscent of classic 16-bit or 32-bit era fighting game sprites with clear, distinct pixel outlines.
#  38%|███████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                                                                                                                                             | 12/32 [04:34<07:55, 23.79s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/john2.mp4:
#  A 2D pixel art animation of a male fighting game character performing a walk cycle. The character is muscular, with short blonde hair partially covered by a red and white baseball cap worn forwards. He wears an open red sleeveless vest, revealing a white t-shirt underneath, paired with dark blue jeans and red and white sneakers. He also has dark fingerless gloves.
#
# He walks confidently and purposefully forward, fists clenched, in a classic side-scrolling perspective. His gait is steady, with a slight swagger, conveying readiness. The animation should be a smooth, continuous loop.
#
# The art style is retro, reminiscent of 90s arcade fighting games (e.g., King of Fighters). The background is a solid, vibrant cyan.
#  41%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                                                                                                                    | 13/32 [04:58<07:32, 23.80s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/jack2.mp4:
#  A 2D pixel art animation featuring a muscular male fighting game character, seen in side view. He has blonde hair and wears a red baseball cap with a white front panel, turned backwards. His attire consists of an open red sleeveless vest over a white short-sleeved t-shirt, dark blue jeans, and red sneakers with white accents. The character is engaged in a continuous, confident walk cycle, moving from left to right across the screen. His fists are clenched, typical of a fighter's idle or walking stance. The animation style is retro pixel art, reminiscent of classic arcade games. The background is a flat, solid, vibrant cyan. The video should present this as a smoothly looping walk animation.
#  44%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                                                                                           | 14/32 [05:11<06:06, 20.38s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/andy.mp4:
#  Pixel art animation, side view. A male fighting game character walks to the right on a solid, bright cyan background.
# The character has shoulder-length blonde hair, mostly covered by a red baseball cap with a white brim and front panel, worn forwards. He's muscular, wearing a red, sleeveless, open vest with white trim, revealing his bare arms. He wears fingerless black gloves.
# His lower body is clad in dark blue jeans and red sneakers with white soles and laces.
# He walks with a confident, slightly bouncy gait, fists clenched, arms swinging rhythmically. The animation is a smooth, continuous walking cycle typical of 2D retro arcade fighting games.
#  47%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                                                                                                   | 15/32 [05:35<06:08, 21.67s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/punk1.mp4:
#  Pixel art animation, 90s arcade fighting game style. Side view of a muscular male character walking confidently to the right.
# He has blonde hair under a red and white baseball cap worn backwards. He wears a red sleeveless vest with white trim over a white, short-sleeved t-shirt with rolled-up sleeves, dark blue denim jeans, dark fingerless gloves, and red high-top sneakers with white soles and laces.
# The animation showcases a classic, slightly bouncy fighting game walk cycle with fluid sprite-based movement.
# The background is a solid, vibrant cyan blue.
# Emphasize clean pixel art, bold colors, and characteristic 2D fighter character animation.
#  50%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                                                                                          | 16/32 [05:57<05:47, 21.71s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/terry.mp4:
#  A 2D pixel art animation featuring a muscular male character in a side-view. He has short blonde hair, mostly covered by a red baseball cap with a white front panel, worn backwards. He's wearing an open, sleeveless red vest (similar to denim) that reveals his bare, well-defined chest and abs. His arms are bare and muscular, ending in black fingerless gloves. He sports dark blue jeans and red and white sneakers.
#
# The character performs a confident, slightly bouncy walk cycle, advancing forward (screen right to left). He maintains a fighting stance with fists clenched and held up near his chest, his body slightly angled. Each step shows a clear shift in weight and leg movement, with arms swinging naturally in opposition. The animation style is reminiscent of classic 16-bit or 32-bit arcade fighting games.
#
# The background is a solid, vibrant cyan color, with no other elements present. The animation loops smoothly.
#  53%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                                                                 | 17/32 [06:21<05:36, 22.43s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/shoto2.mp4:
#  A 2D pixel art animation, profile view, featuring a muscular male character performing a continuous walking cycle. He has short blonde hair, largely covered by a red trucker cap with a prominent white front panel. His outfit includes a red, open sleeveless vest with a small collar, worn over a tight white t-shirt with very short sleeves. He's dressed in dark blue jeans and red-and-white athletic sneakers. Dark fingerless gloves cover his hands, and his fists remain clenched as he walks. He moves with a confident, slightly bouncy gait, arms swinging naturally. The animation style is classic 90s arcade fighting game sprite work. The background is a stark, solid bright cyan. Full body of the character is visible.
#  56%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                                                                         | 18/32 [06:50<05:42, 24.49s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/lee2.mp4:
#  A 2D pixel art animation of the video game character Terry Bogard in a side view. He performs a continuous walking animation loop. Terry is depicted with his blonde hair, wearing his signature red baseball cap with a white front panel, an open red sleeveless vest revealing his muscular arms, dark blue jeans, red fingerless gloves, and red and white sneakers. His fists are clenched as he walks with a confident, slightly bouncy gait; his arms swing naturally with his stride, and his body shows a slight up-and-down motion consistent with a fighting stance. The animation style is that of a classic 90s arcade fighting game sprite. The background is a solid, vibrant cyan color. The overall aesthetic is retro gaming, focusing on clear pixel details and smooth, looping motion.
#  59%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                                                                                | 19/32 [07:15<05:19, 24.55s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/eiji.mp4:
#  Generate a 2D pixel art animation of a classic fighting game character performing a walk cycle.
# The character is a muscular man with short blonde hair, wearing a red and white trucker cap backwards. His attire consists of a red sleeveless vest (appearing to be denim or a similar sturdy material) open over a white short-sleeved t-shirt, dark blue jeans, and red and white sneakers. He also wears brown or dark-colored fingerless gloves.
# He is walking from left to right in a side-view perspective. The walk animation should be smooth and fluid, with a confident gait, typical of a 90s arcade fighting game sprite. His arms swing naturally as he moves.
# The art style is distinctly retro pixel art, featuring clear character outlines and a vibrant, somewhat limited color palette characteristic of the era.
# The background is a solid, bright cyan. The animation should be suitable for a seamless loop, showcasing the character's continuous walking motion.
#  62%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                                       | 20/32 [07:38<04:47, 23.98s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/shoto1.mp4:
#  A 2D pixel art animation of a muscular male video game character in a side view, rendered in a retro gaming sprite style. The character has medium-length blonde hair, mostly covered by a red and white baseball cap worn forwards. He is dressed in a red, collared, sleeveless vest over a white short-sleeved t-shirt, complemented by blue denim jeans and red and white sneakers. Dark fingerless gloves complete his attire. He is performing a smooth walking cycle animation, typical of a side-scrolling game, as if walking in place or steadily advancing. His arms swing naturally in opposition to his legs with each step. The entire animation is set against a solid, vibrant cyan background.
#  66%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                                               | 21/32 [07:57<04:09, 22.70s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/king2.mp4:
#  A 2D pixel art sprite animation of a muscular male character in a side view. He has blonde hair, partially visible under a red baseball cap with a white front panel and brim. He wears a red, open, sleeveless vest with white trim over a white short-sleeved t-shirt, dark blue jeans, and red sneakers with white soles and laces. He also wears dark fingerless gloves.
#
# The character is performing a classic fighting game walk cycle, moving steadily towards the right of the screen. His fists are clenched, and his upper body bobs slightly with each step, maintaining a confident, ready-to-fight stance.
#
# The background is a solid, vibrant bright cyan. The animation should have a retro gaming aesthetic with a smooth, looping walk.
#  69%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                                                      | 22/32 [08:21<03:48, 22.80s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/rat.mp4:
#  Generate a 2D pixel art gaming walk animation of a muscular male fighter character in side view. The character has medium-length blonde hair, partially covered by a red and white baseball cap worn backward. He wears a vibrant red, open sleeveless vest with white trim (possibly over a white undershirt or bare chest), dark blue jeans, red and white sneakers, and black fingerless gloves. He executes a confident, energetic walk cycle, striding purposefully with clenched fists. His arms swing naturally with his steps, and a slight bounce is visible in his movement. The visual style is distinctly retro, evoking 90s arcade fighting game sprites. The background is a solid, bright cyan. Ensure a smooth, looping animation characteristic of classic 2D gaming.
#  72%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                              | 23/32 [08:39<03:12, 21.38s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/big.mp4:
#  A 2D pixel art animation featuring a male fighting game character. He sports short blonde hair, mostly concealed by a red and white baseball cap worn backwards. His attire consists of a red, sleeveless, open vest over a white short-sleeved t-shirt, showcasing a muscular build. He wears blue denim jeans, red and white sneakers, and black fingerless gloves.
#
# Rendered in a side-view perspective, the character executes a smooth, looping walk cycle animation. He maintains a confident fighting stance with clenched fists as he walks.
#
# The entire animation is set against a solid, vibrant cyan background. The aesthetic is classic 2D pixel art, full body shot of the character, reminiscent of 90s arcade fighting games.
#  75%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                     | 24/32 [09:05<03:02, 22.87s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/yuri.mp4:
#  Generate a 2D pixel art gaming walk animation. The subject is a male fighting game character, depicted in a strict side view.
#
# Detailed character appearance: He has a muscular build with blonde hair, mostly covered by a red baseball cap with a white front panel, worn backwards. His iconic outfit features a red, open, sleeveless vest over a white t-shirt (short sleeves visible), paired with dark blue jeans, and red sneakers accented with white. He also wears red fingerless gloves.
#
# Action: The character is performing a continuous, smooth walk cycle, moving from left to right across the screen with a confident gait. The animation should loop seamlessly.
#
# Artistic style: The visual style is classic retro pixel art, characteristic of 90s arcade fighting games. This includes well-defined character sprites, a vibrant yet limited color palette, and fluid frame-by-frame animation.
#
# Background: The entire animation is set against a solid, bright, untextured cyan background, ensuring the character sprite is the sole focus.
#
# The animation should capture the essence of a classic 2D game character's movement.
#  78%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                            | 25/32 [09:25<02:34, 22.10s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/todo.mp4:
#  A 2D pixel art animation in a side-scrolling fighting game style. The scene features a muscular male character performing a continuous walking animation. He has medium-length blonde hair, partially covered by a red baseball cap with a white front panel, worn forwards. He's dressed in a red, open sleeveless vest over a white short-sleeved t-shirt, dark blue jeans, and red and white sneakers. Dark fingerless gloves are on his hands, which are clenched into fists. He walks with a confident, slightly bouncy stride, arms swinging naturally from a side view. The background is a solid, bright cyan blue.
#  81%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                    | 26/32 [09:45<02:09, 21.54s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/king.mp4:
#  A detailed pixel art animation of a male fighter character from a classic 2D fighting game, shown in side view. The character has short blonde hair and wears a signature red baseball cap backwards with a white front panel and brim. His attire includes a red, open sleeveless vest over a white short-sleeved t-shirt, dark blue denim jeans, and red sneakers with white soles and laces. He has a muscular physique. The animation depicts a smooth walk cycle as he advances purposefully. He maintains a fighting stance, fists clenched and held up, arms bent, moving rhythmically with his steps. The background is a stark, solid bright cyan. The style is distinctly retro pixel art, evoking 90s arcade fighting games.
#  84%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                           | 27/32 [09:57<01:33, 18.65s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/brian.mp4:
#  Pixel art animation, 2D side view. A muscular male character with blonde hair, wearing a red backwards baseball cap, a red sleeveless vest over a white undershirt (or with white trim), dark blue denim jeans, and red sneakers with white soles and laces. He has a confident demeanor.
#
# The character is performing a walking animation cycle, striding purposefully from left to right. His arms are bent at the elbows, swinging in time with his steps, fists clenched as if ready for action. His body has a slight bounce as he moves.
#
# The background is a solid, vibrant cyan color. The animation style is reminiscent of classic 2D fighting games.
#  88%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                  | 28/32 [10:14<01:12, 18.11s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/sold1.mp4:
#  Pixel art, 2D fighting game sprite animation.
# A muscular male character with blonde hair, mostly covered by a backwards red baseball cap with a white front panel. He wears an open red sleeveless vest (possibly denim-like material) over a tight white short-sleeved t-shirt, and red fingerless gloves. His lower body is clad in dark blue jeans and red sneakers with white accents and soles.
#
# The character is performing a walk cycle, moving from screen left towards screen right (or simply "walking forward"). His arms swing naturally with his stride, and his posture is upright and confident. The animation is smooth, characteristic of classic arcade fighting games.
#
# The scene is set against a solid, bright cyan background. The overall aesthetic is retro gaming. Side view.
#  91%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                          | 29/32 [10:33<00:54, 18.33s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/sold3.mp4:
#  A 2D pixel art animation of a male fighting game character performing a walk cycle, moving from left to right.
#
# The character is muscular. He wears a red baseball cap (worn forwards) with a white circular logo or design on the front. Medium-length blond hair is visible at the back and sides beneath the cap.
# He sports a sleeveless, open red vest with white trim, showcasing his bare, muscular chest and arms. He wears dark, fingerless gloves.
# His lower body is clad in dark blue denim jeans, and he sports red and white sneakers.
#
# The animation style is a classic side-view sprite walk cycle, characteristic of 90s arcade fighting games, with a confident and purposeful stride.
# The background is a solid, vibrant cyan color.
#  94%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                 | 30/32 [10:54<00:38, 19.02s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/sold2.mp4:
#  Create a retro 2D pixel art animation of a male fighting game character walking. Seen from a side view, the character is muscular, with blonde hair peeking from under a red baseball cap worn backwards. He sports an open red sleeveless vest, a white short-sleeved shirt with sleeves rolled up, dark fingerless gloves, dark blue jeans, and red and white sneakers.
#
# He walks with a confident, slightly bouncy gait from left to right across the screen, fists clenched and arms bent in a classic fighting stance. This is a continuous walk cycle animation. The background is a solid, bright cyan, emphasizing the character sprite. The overall aesthetic is reminiscent of 90s arcade fighting games.
#  97%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎        | 31/32 [11:12<00:18, 18.85s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/john.mp4:
#  A 2D pixel art animation of the video game character Terry Bogard from King of Fighters. He is depicted in a side view, full body shot. Terry has blonde hair mostly covered by a red baseball cap worn backwards. He wears his signature red, open, sleeveless vest over a white short-sleeved t-shirt, showcasing his muscular arms. He also wears red fingerless gloves, dark blue denim jeans, and red and white sneakers.
#
# The character is performing a classic fighting game idle walk or ready stance animation: walking in place with a slight, rhythmic bounce and a subtle swagger. His fists are clenched, arms bent at the elbows and swinging naturally with his movement. His torso subtly twists with each step. The animation loop is smooth and continuous.
#
# The background is a solid, bright cyan. The overall style is reminiscent of retro arcade fighting games.
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 32/32 [11:31<00:00, 21.62s/it]
# gend prompt for /Users/l_y_o/Work/godmodeai_video_training25/training_data/artoffighting_beatsofrage_remix3/training_videos/walk/heid.mp4:
#  Pixel art animation, 2D sprite style, reminiscent of classic 90s fighting games.
# A muscular male character with short blonde hair is featured. He wears a red and white baseball cap (worn forwards), a red sleeveless denim-style vest open over a white, short-sleeved t-shirt, dark blue jeans, and red and white sneakers. He also wears dark fingerless gloves.
# The character is performing a confident, slightly swaggering walk cycle animation, viewed from the side. His fists are clenched and his arms swing rhythmically as he walks across the frame. The animation should be a loop.
# The background is a solid, bright cyan color.

# %%
pfn
# Out:
# 'Billy.txt'
# ERROR! Session/line number was not unique in database. History logging moved to new session 1340
