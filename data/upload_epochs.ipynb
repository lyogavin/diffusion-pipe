# %%
base_path = "/root/data/diffusion_pipe_training_runs/wan_video/20250530_03-37-03"

# %%
repoid = "godmodeai_wan_hadouken"

# %%
# !huggingface-cli repo create --private lyogavin/{repoid}
# Out:
# Successfully created lyogavin/godmodeai_wan_hadouken on the Hub.
# Your repo is now available at https://huggingface.co/lyogavin/godmodeai_wan_hadouken

# %%
from glob import glob
from tqdm import tqdm


start_epoch = 130



for f in tqdm(glob(f"{base_path}/epoch*")):
    #print(f)
    #continue
    num = f.split("/")[-1].replace("epoch","")
    num = int(num)
    # print(num)
    if num >= start_epoch:
        # !huggingface-cli upload lyogavin/{repoid}  {f} epoch{num}
# Out:
#   0%|          | 0/35 [00:00<?, ?it/s]
# Start hashing 3 files.
# Finished hashing 3 files.
# adapter_model.safetensors: 100%|█████████████| 307M/307M [00:12<00:00, 24.4MB/s]
# https://huggingface.co/lyogavin/godmodeai_wan_hadouken/tree/main/epoch130
#  74%|███████▍  | 26/35 [00:14<00:05,  1.74it/s]
# Start hashing 3 files.
# Finished hashing 3 files.
# adapter_model.safetensors: 100%|█████████████| 307M/307M [00:15<00:00, 19.3MB/s]
# https://huggingface.co/lyogavin/godmodeai_wan_hadouken/tree/main/epoch135
#  77%|███████▋  | 27/35 [00:33<00:12,  1.53s/it]
# Start hashing 3 files.
# Finished hashing 3 files.
# adapter_model.safetensors: 100%|█████████████| 307M/307M [00:12<00:00, 24.4MB/s]
# https://huggingface.co/lyogavin/godmodeai_wan_hadouken/tree/main/epoch140
#  80%|████████  | 28/35 [00:48<00:17,  2.47s/it]
# Start hashing 3 files.
# Finished hashing 3 files.
# adapter_model.safetensors: 100%|█████████████| 307M/307M [00:13<00:00, 22.1MB/s]
# https://huggingface.co/lyogavin/godmodeai_wan_hadouken/tree/main/epoch145
#  83%|████████▎ | 29/35 [01:05<00:22,  3.73s/it]
# Start hashing 3 files.
# Finished hashing 3 files.
# adapter_model.safetensors: 100%|█████████████| 307M/307M [00:12<00:00, 24.3MB/s]
# https://huggingface.co/lyogavin/godmodeai_wan_hadouken/tree/main/epoch150
#  86%|████████▌ | 30/35 [01:20<00:25,  5.04s/it]
# Start hashing 3 files.
# Finished hashing 3 files.
# adapter_model.safetensors: 100%|█████████████| 307M/307M [00:12<00:00, 24.3MB/s]
# https://huggingface.co/lyogavin/godmodeai_wan_hadouken/tree/main/epoch155
#  89%|████████▊ | 31/35 [01:35<00:25,  6.44s/it]
# Start hashing 3 files.
# Finished hashing 3 files.
# adapter_model.safetensors: 100%|█████████████| 307M/307M [00:11<00:00, 26.7MB/s]
# https://huggingface.co/lyogavin/godmodeai_wan_hadouken/tree/main/epoch160
#  91%|█████████▏| 32/35 [01:51<00:24,  8.06s/it]
# Start hashing 3 files.
# Finished hashing 3 files.
# adapter_model.safetensors: 100%|█████████████| 307M/307M [00:12<00:00, 23.9MB/s]
# https://huggingface.co/lyogavin/godmodeai_wan_hadouken/tree/main/epoch165
#  94%|█████████▍| 33/35 [02:07<00:18,  9.44s/it]
# Start hashing 3 files.
# Finished hashing 3 files.
# adapter_model.safetensors: 100%|█████████████| 307M/307M [00:12<00:00, 25.0MB/s]
# https://huggingface.co/lyogavin/godmodeai_wan_hadouken/tree/main/epoch170
#  97%|█████████▋| 34/35 [02:21<00:10, 10.60s/it]
# Start hashing 3 files.
# Finished hashing 3 files.
# adapter_model.safetensors: 100%|█████████████| 307M/307M [00:11<00:00, 25.7MB/s]
# https://huggingface.co/lyogavin/godmodeai_wan_hadouken/tree/main/epoch175
# 100%|██████████| 35/35 [02:36<00:00,  4.48s/it]
